# %%
import os
from argparse import Namespace
from collections import Counter
import json
import re
import string

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm

# %%
class Vocabulary(object):
    def __init__(self, token_to_idx=None):
        if token_to_idx is None:
            token_to_idx = {}
        self._token_to_idx = token_to_idx
        self._idx_to_token = {idx: token 
                             for token, idx in self._token_to_idx.items()}

    def to_serializable(self):
        return {'token_to_idx': self._token_to_idx}

    @classmethod
    def from_serializable(cls, contents):
        return cls(**contents)

    def add_token(self, token):
        if token in self._token_to_idx:
            index = self._token_to_idx[token]
        else:
            index = len(self._token_to_idx)
            self._token_to_idx[token] = index
            self._idx_to_token[index] = token
        return index

    def add_many(self, tokens):
        return [self.add_token(token) for token in tokens]

    def lookup_token(self, token):
        return self._token_to_idx[token]

    def lookup_index(self, index):
        if index not in self._idx_to_token:
            raise KeyError("the index (%d) is not in the Vocabulary" % index)
        return self._idx_to_token[index]

    def __str__(self):
        return "<Vocabulary(size=%d)>" % len(self)

    def __len__(self):
        return len(self._token_to_idx)

# %%
class SequenceVocabulary(Vocabulary):
    def __init__(self, token_to_idx=None, unk_token="<UNK>",
                 mask_token="<MASK>", begin_seq_token="<BEGIN>",
                 end_seq_token="<END>"):
        
        super(SequenceVocabulary, self).__init__(token_to_idx)

        self._mask_token = mask_token
        self._unk_token = unk_token
        self._begin_seq_token = begin_seq_token
        self._end_seq_token = end_seq_token

        self.mask_index = self.add_token(self._mask_token)
        self.unk_index = self.add_token(self._unk_token)
        self.begin_seq_index = self.add_token(self._begin_seq_token)
        self.end_seq_index = self.add_token(self._end_seq_token)

    def to_serializable(self):
        contents = super(SequenceVocabulary, self).to_serializable()
        contents.update({'unk_token': self._unk_token,
                         'mask_token': self._mask_token,
                         'begin_seq_token': self._begin_seq_token,
                         'end_seq_token': self._end_seq_token})
        return contents

    def lookup_token(self, token):
        if self.unk_index >= 0:
            return self._token_to_idx.get(token, self.unk_index)
        else:
            return self._token_to_idx[token]

# %%
class SurnameVectorizer(object):
    def __init__(self, char_vocab, nationality_vocab):
        self.char_vocab = char_vocab
        self.nationality_vocab = nationality_vocab

    def vectorize(self, surname, vector_length=-1):
        indices = [self.char_vocab.begin_seq_index]
        indices.extend(self.char_vocab.lookup_token(token) for token in surname)
        indices.append(self.char_vocab.end_seq_index)

        if vector_length < 0:
            vector_length = len(indices) - 1

        from_vector = np.zeros(vector_length, dtype=np.int64)
        from_indices = indices[:-1]
        from_vector[:len(from_indices)] = from_indices
        from_vector[len(from_indices):] = self.char_vocab.mask_index

        to_vector = np.zeros(vector_length, dtype=np.int64)
        to_indices = indices[1:]
        to_vector[:len(to_indices)] = to_indices
        to_vector[len(to_indices):] = self.char_vocab.mask_index

        return from_vector, to_vector

    @classmethod
    def from_dataframe(cls, surname_df):
        char_vocab = SequenceVocabulary()
        nationality_vocab = Vocabulary()

        for index, row in surname_df.iterrows():
            for char in row.surname:
                char_vocab.add_token(char)
            nationality_vocab.add_token(row.nationality)

        return cls(char_vocab, nationality_vocab)

    @classmethod
    def from_serializable(cls, contents):
        char_vocab = SequenceVocabulary.from_serializable(contents['char_vocab'])
        nat_vocab = Vocabulary.from_serializable(contents['nationality_vocab'])
        return cls(char_vocab=char_vocab, nationality_vocab=nat_vocab)

    def to_serializable(self):
        return {'char_vocab': self.char_vocab.to_serializable(),
                'nationality_vocab': self.nationality_vocab.to_serializable()}

# %%
class SurnameDataset(Dataset):
    def __init__(self, surname_df, vectorizer):
        self.surname_df = surname_df
        self._vectorizer = vectorizer
        self._max_seq_length = max(map(len, self.surname_df.surname)) + 2

        self.train_df = self.surname_df[self.surname_df.split == 'train']
        self.train_size = len(self.train_df)
        self.val_df = self.surname_df[self.surname_df.split == 'val']
        self.validation_size = len(self.val_df)
        self.test_df = self.surname_df[self.surname_df.split == 'test']
        self.test_size = len(self.test_df)

        self._lookup_dict = {'train': (self.train_df, self.train_size),
                             'val': (self.val_df, self.validation_size),
                             'test': (self.test_df, self.test_size)}
        self.set_split('train')

    @classmethod
    def load_dataset_and_make_vectorizer(cls, surname_csv):
        surname_df = pd.read_csv(surname_csv)
        return cls(surname_df, SurnameVectorizer.from_dataframe(surname_df))

    @classmethod
    def load_dataset_and_load_vectorizer(cls, surname_csv, vectorizer_filepath):
        surname_df = pd.read_csv(surname_csv)
        vectorizer = cls.load_vectorizer_only(vectorizer_filepath)
        return cls(surname_df, vectorizer)

    @staticmethod
    def load_vectorizer_only(vectorizer_filepath):
        with open(vectorizer_filepath) as fp:
            return SurnameVectorizer.from_serializable(json.load(fp))

    def save_vectorizer(self, vectorizer_filepath):
        with open(vectorizer_filepath, "w") as fp:
            json.dump(self._vectorizer.to_serializable(), fp)

    def get_vectorizer(self):
        return self._vectorizer

    def set_split(self, split="train"):
        self._target_split = split
        self._target_df, self._target_size = self._lookup_dict[split]

    def __len__(self):
        return self._target_size

    def __getitem__(self, index):
        row = self._target_df.iloc[index]
        from_vector, to_vector = self._vectorizer.vectorize(row.surname, self._max_seq_length)
        nationality_index = self._vectorizer.nationality_vocab.lookup_token(row.nationality)
        return {'x_data': from_vector,
                'y_target': to_vector,
                'class_index': nationality_index}

    def get_num_batches(self, batch_size):
        return len(self) // batch_size

# %%
def generate_batches(dataset, batch_size, shuffle=True,
                    drop_last=True, device="cpu"):
    dataloader = DataLoader(dataset=dataset, batch_size=batch_size,
                          shuffle=shuffle, drop_last=drop_last)
    for data_dict in dataloader:
        out_data_dict = {}
        for name, tensor in data_dict.items():
            out_data_dict[name] = data_dict[name].to(device)
        yield out_data_dict

# %%
class SurnameGenerationModel(nn.Module):
    def __init__(self, char_embedding_size, char_vocab_size, num_nationalities,
                rnn_hidden_size, batch_first=True, padding_idx=0, dropout_p=0.5):
        super(SurnameGenerationModel, self).__init__()
        self.char_emb = nn.Embedding(char_vocab_size, char_embedding_size, padding_idx=padding_idx)
        self.nation_emb = nn.Embedding(num_nationalities, rnn_hidden_size)
        self.rnn = nn.GRU(char_embedding_size, rnn_hidden_size, batch_first=batch_first)
        self.fc = nn.Linear(rnn_hidden_size, char_vocab_size)
        self._dropout_p = dropout_p

    def forward(self, x_in, nationality_index, apply_softmax=False):
        x_embedded = self.char_emb(x_in)
        nationality_embedded = self.nation_emb(nationality_index).unsqueeze(0)
        y_out, _ = self.rnn(x_embedded, nationality_embedded)
        
        batch_size, seq_size, feat_size = y_out.shape
        y_out = y_out.contiguous().view(batch_size * seq_size, feat_size)
        y_out = self.fc(F.dropout(y_out, p=self._dropout_p))
        
        if apply_softmax:
            y_out = F.softmax(y_out, dim=1)
        new_feat_size = y_out.shape[-1]
        return y_out.view(batch_size, seq_size, new_feat_size)

# %%
def sample_from_model(model, vectorizer, nationalities, sample_size=20, temperature=1.0):
    num_samples = len(nationalities)
    begin_seq_index = [vectorizer.char_vocab.begin_seq_index for _ in range(num_samples)]
    indices = [torch.tensor(begin_seq_index, dtype=torch.int64).unsqueeze(dim=1)]
    nationality_indices = torch.tensor(nationalities, dtype=torch.int64).unsqueeze(dim=0)
    h_t = model.nation_emb(nationality_indices)

    for time_step in range(sample_size):
        x_t = indices[time_step]
        x_emb_t = model.char_emb(x_t)
        rnn_out_t, h_t = model.rnn(x_emb_t, h_t)
        prediction_vector = model.fc(rnn_out_t.squeeze(dim=1))
        probability_vector = F.softmax(prediction_vector / temperature, dim=1)
        indices.append(torch.multinomial(probability_vector, num_samples=1))
    return torch.stack(indices).squeeze().permute(1, 0)

def decode_samples(sampled_indices, vectorizer):
    decoded_surnames = []
    vocab = vectorizer.char_vocab
    for sample_index in range(sampled_indices.shape[0]):
        surname = ""
        for time_step in range(sampled_indices.shape[1]):
            sample_item = sampled_indices[sample_index, time_step].item()
            if sample_item == vocab.begin_seq_index:
                continue
            elif sample_item == vocab.end_seq_index:
                break
            else:
                surname += vocab.lookup_index(sample_item)
        decoded_surnames.append(surname)
    return decoded_surnames

# %%
def make_train_state(args):
    return {'stop_early': False,
            'early_stopping_step': 0,
            'early_stopping_best_val': 1e8,
            'learning_rate': args.learning_rate,
            'epoch_index': 0,
            'train_loss': [],
            'train_acc': [],
            'val_loss': [],
            'val_acc': [],
            'test_loss': -1,
            'test_acc': -1,
            'model_filename': args.model_state_file}

def update_train_state(args, model, train_state):
    if train_state['epoch_index'] == 0:
        torch.save(model.state_dict(), train_state['model_filename'])
        train_state['stop_early'] = False
    elif train_state['epoch_index'] >= 1:
        loss_tm1, loss_t = train_state['val_loss'][-2:]
        if loss_t >= loss_tm1:
            train_state['early_stopping_step'] += 1
        else:
            if loss_t < train_state['early_stopping_best_val']:
                torch.save(model.state_dict(), train_state['model_filename'])
                train_state['early_stopping_best_val'] = loss_t
            train_state['early_stopping_step'] = 0
        train_state['stop_early'] = train_state['early_stopping_step'] >= args.early_stopping_criteria
    return train_state

# %%
def normalize_sizes(y_pred, y_true):
    if len(y_pred.size()) == 3:
        y_pred = y_pred.contiguous().view(-1, y_pred.size(2))
    if len(y_true.size()) == 2:
        y_true = y_true.contiguous().view(-1)
    return y_pred, y_true

def compute_accuracy(y_pred, y_true, mask_index):
    y_pred, y_true = normalize_sizes(y_pred, y_true)
    _, y_pred_indices = y_pred.max(dim=1)
    correct_indices = torch.eq(y_pred_indices, y_true).float()
    valid_indices = torch.ne(y_true, mask_index).float()
    return (correct_indices * valid_indices).sum().item() / valid_indices.sum().item() * 100

def sequence_loss(y_pred, y_true, mask_index):
    y_pred, y_true = normalize_sizes(y_pred, y_true)
    return F.cross_entropy(y_pred, y_true, ignore_index=mask_index)

def set_seed_everywhere(seed, cuda):
    np.random.seed(seed)
    torch.manual_seed(seed)
    if cuda:
        torch.cuda.manual_seed_all(seed)

def handle_dirs(dirpath):
    if not os.path.exists(dirpath):
        os.makedirs(dirpath)

# %%
args = Namespace(
    surname_csv="surnames_with_splits.csv",
    vectorizer_file="vectorizer.json",
    model_state_file="model.pth",
    save_dir="model_storage/ch7/model2_conditioned_surname_generation",
    char_embedding_size=32,
    rnn_hidden_size=32,
    seed=1337,
    learning_rate=0.001,
    batch_size=128,
    num_epochs=50,
    early_stopping_criteria=5,
    catch_keyboard_interrupt=True,
    cuda=True,
    expand_filepaths_to_save_dir=True,
    reload_from_files=False,
)

if args.expand_filepaths_to_save_dir:
    args.vectorizer_file = os.path.join(args.save_dir, args.vectorizer_file)
    args.model_state_file = os.path.join(args.save_dir, args.model_state_file)
    print(f"Expanded filepaths:\n\t{args.vectorizer_file}\n\t{args.model_state_file}")
# Out:
# Expanded filepaths:
# 	model_storage/ch7/model2_conditioned_surname_generation\vectorizer.json
# 	model_storage/ch7/model2_conditioned_surname_generation\model.pth

# %%
args.device = torch.device("cuda" if args.cuda and torch.cuda.is_available() else "cpu")
print(f"Using {'CUDA' if args.device.type == 'cuda' else 'CPU'}")

set_seed_everywhere(args.seed, args.cuda)
handle_dirs(args.save_dir)
# Out:
# Using CPU

# %%
if args.reload_from_files:
    dataset = SurnameDataset.load_dataset_and_load_vectorizer(args.surname_csv, args.vectorizer_file)
else:
    dataset = SurnameDataset.load_dataset_and_make_vectorizer(args.surname_csv)
    dataset.save_vectorizer(args.vectorizer_file)
vectorizer = dataset.get_vectorizer()

# %%
model = SurnameGenerationModel(
    char_embedding_size=args.char_embedding_size,
    char_vocab_size=len(vectorizer.char_vocab),
    num_nationalities=len(vectorizer.nationality_vocab),
    rnn_hidden_size=args.rnn_hidden_size,
    padding_idx=vectorizer.char_vocab.mask_index,
    dropout_p=0.5
).to(args.device)
mask_index = vectorizer.char_vocab.mask_index

# %%
optimizer = optim.Adam(model.parameters(), lr=args.learning_rate)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=1)
train_state = make_train_state(args)

# %%
try:
    epoch_bar = tqdm(desc='training routine', total=args.num_epochs, position=0)
    
    for epoch_index in range(args.num_epochs):
        # 训练阶段
        dataset.set_split('train')
        batch_generator = generate_batches(dataset, args.batch_size, device=args.device)
        running_loss = 0.0
        running_acc = 0.0
        model.train()
        
        train_bar = tqdm(desc='split=train', total=dataset.get_num_batches(args.batch_size), position=1)
        for batch_index, batch_dict in enumerate(batch_generator):
            optimizer.zero_grad()
            y_pred = model(batch_dict['x_data'], batch_dict['class_index'])
            loss = sequence_loss(y_pred, batch_dict['y_target'], mask_index)
            loss.backward()
            optimizer.step()
            
            running_loss += (loss.item() - running_loss) / (batch_index + 1)
            acc_t = compute_accuracy(y_pred, batch_dict['y_target'], mask_index)
            running_acc += (acc_t - running_acc) / (batch_index + 1)
            
            train_bar.set_postfix(loss=running_loss, acc=running_acc)
            train_bar.update()
        train_state['train_loss'].append(running_loss)
        train_state['train_acc'].append(running_acc)

        # 验证阶段
        dataset.set_split('val')
        batch_generator = generate_batches(dataset, args.batch_size, device=args.device)
        running_loss = 0.0
        running_acc = 0.0
        model.eval()
        
        val_bar = tqdm(desc='split=val', total=dataset.get_num_batches(args.batch_size), position=1)
        for batch_index, batch_dict in enumerate(batch_generator):
            with torch.no_grad():
                y_pred = model(batch_dict['x_data'], batch_dict['class_index'])
                loss = sequence_loss(y_pred, batch_dict['y_target'], mask_index)
            
            running_loss += (loss.item() - running_loss) / (batch_index + 1)
            acc_t = compute_accuracy(y_pred, batch_dict['y_target'], mask_index)
            running_acc += (acc_t - running_acc) / (batch_index + 1)
            
            val_bar.set_postfix(loss=running_loss, acc=running_acc)
            val_bar.update()
        train_state['val_loss'].append(running_loss)
        train_state['val_acc'].append(running_acc)

        # 更新训练状态
        train_state = update_train_state(args, model, train_state)
        scheduler.step(train_state['val_loss'][-1])
        
        # 采样演示
        model.cpu()
        nationalities = np.random.choice(len(vectorizer.nationality_vocab), size=2)
        sampled_indices = sample_from_model(model, vectorizer, nationalities, temperature=0.7)
        sampled_names = decode_samples(sampled_indices, vectorizer)
        epoch_bar.set_postfix(sample1=f"{vectorizer.nationality_vocab.lookup_index(nationalities[0])}->{sampled_names[0]}",
                             sample2=f"{vectorizer.nationality_vocab.lookup_index(nationalities[1])}->{sampled_names[1]}")
        model.to(args.device)
        
        epoch_bar.update()
        if train_state['stop_early']:
            break

except KeyboardInterrupt:
    print("Exiting loop")
# Out:
# training routine:   0%|          | 0/50 [00:00<?, ?it/s]
# split=train:   0%|          | 0/60 [00:00<?, ?it/s]
# split=train:   0%|          | 0/60 [00:00<?, ?it/s, acc=0.815, loss=4.54]
# split=train:   2%|▏         | 1/60 [00:00<00:04, 12.66it/s, acc=0.919, loss=4.54]
# split=train:   3%|▎         | 2/60 [00:00<00:03, 18.87it/s, acc=1.02, loss=4.52]
# split=train:   5%|▌         | 3/60 [00:00<00:02, 28.04it/s, acc=1.02, loss=4.52]
# split=train:   5%|▌         | 3/60 [00:00<00:02, 28.04it/s, acc=1.1, loss=4.52]
# split=train:   7%|▋         | 4/60 [00:00<00:01, 28.04it/s, acc=1.18, loss=4.51]
# split=train:   8%|▊         | 5/60 [00:00<00:01, 28.04it/s, acc=1.26, loss=4.5]
# split=train:  10%|█         | 6/60 [00:00<00:01, 28.04it/s, acc=1.33, loss=4.5]
# split=train:  12%|█▏        | 7/60 [00:00<00:01, 32.99it/s, acc=1.33, loss=4.5]
# split=train:  12%|█▏        | 7/60 [00:00<00:01, 32.99it/s, acc=1.4, loss=4.49]
# split=train:  13%|█▎        | 8/60 [00:00<00:01, 32.99it/s, acc=1.48, loss=4.48]
# split=train:  15%|█▌        | 9/60 [00:00<00:01, 32.99it/s, acc=1.51, loss=4.48]
# split=train:  17%|█▋        | 10/60 [00:00<00:01, 32.99it/s, acc=1.57, loss=4.47]
# split=train:  18%|█▊        | 11/60 [00:00<00:01, 33.70it/s, acc=1.57, loss=4.47]
# split=train:  18%|█▊        | 11/60 [00:00<00:01, 33.70it/s, acc=1.67, loss=4.46]
# split=train:  20%|██        | 12/60 [00:00<00:01, 33.70it/s, acc=1.76, loss=4.46]
# split=train:  22%|██▏       | 13/60 [00:00<00:01, 33.70it/s, acc=1.89, loss=4.45]
# split=train:  23%|██▎       | 14/60 [00:00<00:01, 33.70it/s, acc=1.94, loss=4.45]
# split=train:  25%|██▌       | 15/60 [00:00<00:01, 35.75it/s, acc=1.94, loss=4.45]
# split=train:  25%|██▌       | 15/60 [00:00<00:01, 35.75it/s, acc=2.04, loss=4.44]
# split=train:  27%|██▋       | 16/60 [00:00<00:01, 35.75it/s, acc=2.19, loss=4.44]
# split=train:  28%|██▊       | 17/60 [00:00<00:01, 35.75it/s, acc=2.31, loss=4.43]
# split=train:  30%|███       | 18/60 [00:00<00:01, 35.75it/s, acc=2.36, loss=4.42]
# split=train:  32%|███▏      | 19/60 [00:00<00:01, 36.58it/s, acc=2.36, loss=4.42]
# split=train:  32%|███▏      | 19/60 [00:00<00:01, 36.58it/s, acc=2.52, loss=4.42]
# split=train:  33%|███▎      | 20/60 [00:00<00:01, 36.58it/s, acc=2.65, loss=4.41]
# split=train:  35%|███▌      | 21/60 [00:00<00:01, 36.58it/s, acc=2.76, loss=4.4]
# split=train:  37%|███▋      | 22/60 [00:00<00:01, 36.58it/s, acc=2.92, loss=4.4]
# split=train:  38%|███▊      | 23/60 [00:00<00:01, 36.58it/s, acc=3.09, loss=4.39]
# split=train:  40%|████      | 24/60 [00:00<00:00, 39.53it/s, acc=3.09, loss=4.39]
# split=train:  40%|████      | 24/60 [00:00<00:00, 39.53it/s, acc=3.2, loss=4.38]
# split=train:  42%|████▏     | 25/60 [00:00<00:00, 39.53it/s, acc=3.37, loss=4.38]
# split=train:  43%|████▎     | 26/60 [00:00<00:00, 39.53it/s, acc=3.53, loss=4.37]
# split=train:  45%|████▌     | 27/60 [00:00<00:00, 39.53it/s, acc=3.71, loss=4.36]
# split=train:  47%|████▋     | 28/60 [00:00<00:00, 38.95it/s, acc=3.71, loss=4.36]
# split=train:  47%|████▋     | 28/60 [00:00<00:00, 38.95it/s, acc=3.92, loss=4.36]
# split=train:  48%|████▊     | 29/60 [00:00<00:00, 38.95it/s, acc=4.11, loss=4.35]
# split=train:  50%|█████     | 30/60 [00:00<00:00, 38.95it/s, acc=4.34, loss=4.34]
# split=train:  52%|█████▏    | 31/60 [00:00<00:00, 38.95it/s, acc=4.53, loss=4.33]
# split=train:  53%|█████▎    | 32/60 [00:00<00:00, 39.15it/s, acc=4.53, loss=4.33]
# split=train:  53%|█████▎    | 32/60 [00:00<00:00, 39.15it/s, acc=4.69, loss=4.32]
# split=train:  55%|█████▌    | 33/60 [00:00<00:00, 39.15it/s, acc=4.92, loss=4.31]
# split=train:  57%|█████▋    | 34/60 [00:00<00:00, 39.15it/s, acc=5.11, loss=4.3]
# split=train:  58%|█████▊    | 35/60 [00:00<00:00, 39.15it/s, acc=5.28, loss=4.3]
# split=train:  60%|██████    | 36/60 [00:00<00:00, 37.81it/s, acc=5.28, loss=4.3]
# split=train:  60%|██████    | 36/60 [00:00<00:00, 37.81it/s, acc=5.46, loss=4.29]
# split=train:  62%|██████▏   | 37/60 [00:01<00:00, 37.81it/s, acc=5.61, loss=4.28]
# split=train:  63%|██████▎   | 38/60 [00:01<00:00, 37.81it/s, acc=5.75, loss=4.27]
# split=train:  65%|██████▌   | 39/60 [00:01<00:00, 37.81it/s, acc=5.89, loss=4.26]
# split=train:  67%|██████▋   | 40/60 [00:01<00:00, 37.81it/s, acc=6.09, loss=4.25]
# split=train:  68%|██████▊   | 41/60 [00:01<00:00, 38.45it/s, acc=6.09, loss=4.25]
# split=train:  68%|██████▊   | 41/60 [00:01<00:00, 38.45it/s, acc=6.28, loss=4.24]
# split=train:  70%|███████   | 42/60 [00:01<00:00, 38.45it/s, acc=6.45, loss=4.23]
# split=train:  72%|███████▏  | 43/60 [00:01<00:00, 38.45it/s, acc=6.61, loss=4.22]
# split=train:  73%|███████▎  | 44/60 [00:01<00:00, 38.45it/s, acc=6.75, loss=4.21]
# split=train:  75%|███████▌  | 45/60 [00:01<00:00, 38.56it/s, acc=6.75, loss=4.21]
# split=train:  75%|███████▌  | 45/60 [00:01<00:00, 38.56it/s, acc=6.95, loss=4.2]
# split=train:  77%|███████▋  | 46/60 [00:01<00:00, 38.56it/s, acc=7.06, loss=4.18]
# split=train:  78%|███████▊  | 47/60 [00:01<00:00, 38.56it/s, acc=7.16, loss=4.17]
# split=train:  80%|████████  | 48/60 [00:01<00:00, 38.56it/s, acc=7.3, loss=4.16]
# split=train:  82%|████████▏ | 49/60 [00:01<00:00, 38.56it/s, acc=7.41, loss=4.15]
# split=train:  83%|████████▎ | 50/60 [00:01<00:00, 39.25it/s, acc=7.41, loss=4.15]
# split=train:  83%|████████▎ | 50/60 [00:01<00:00, 39.25it/s, acc=7.51, loss=4.14]
# split=train:  85%|████████▌ | 51/60 [00:01<00:00, 39.25it/s, acc=7.65, loss=4.13]
# split=train:  87%|████████▋ | 52/60 [00:01<00:00, 39.25it/s, acc=7.78, loss=4.12]
# split=train:  88%|████████▊ | 53/60 [00:01<00:00, 39.25it/s, acc=7.88, loss=4.11]
# split=train:  90%|█████████ | 54/60 [00:01<00:00, 38.19it/s, acc=7.88, loss=4.11]
# split=train:  90%|█████████ | 54/60 [00:01<00:00, 38.19it/s, acc=8, loss=4.1]
# split=train:  92%|█████████▏| 55/60 [00:01<00:00, 38.19it/s, acc=8.1, loss=4.09]
# split=train:  93%|█████████▎| 56/60 [00:01<00:00, 38.19it/s, acc=8.22, loss=4.07]
# split=train:  95%|█████████▌| 57/60 [00:01<00:00, 38.19it/s, acc=8.29, loss=4.06]
# split=train:  97%|█████████▋| 58/60 [00:01<00:00, 38.06it/s, acc=8.29, loss=4.06]
# split=train:  97%|█████████▋| 58/60 [00:01<00:00, 38.06it/s, acc=8.38, loss=4.05]
# split=train:  98%|█████████▊| 59/60 [00:01<00:00, 38.06it/s, acc=8.46, loss=4.04]
# split=val:   0%|          | 0/12 [00:00<?, ?it/s]
# split=val:   0%|          | 0/12 [00:00<?, ?it/s, acc=15.1, loss=3.37]
# split=val:   8%|▊         | 1/12 [00:00<00:00, 28.56it/s, acc=14.6, loss=3.37]
# split=val:  17%|█▋        | 2/12 [00:00<00:00, 38.45it/s, acc=14.3, loss=3.38]
# split=val:  25%|██▌       | 3/12 [00:00<00:00, 44.78it/s, acc=14.3, loss=3.39]
# split=val:  33%|███▎      | 4/12 [00:00<00:00, 48.19it/s, acc=14.1, loss=3.39]
# split=val:  42%|████▏     | 5/12 [00:00<00:00, 50.00it/s, acc=13.9, loss=3.4]
# split=val:  50%|█████     | 6/12 [00:00<00:00, 59.41it/s, acc=13.9, loss=3.4]
# split=val:  50%|█████     | 6/12 [00:00<00:00, 59.41it/s, acc=13.8, loss=3.4]
# split=val:  58%|█████▊    | 7/12 [00:00<00:00, 59.41it/s, acc=13.8, loss=3.4]
# split=val:  67%|██████▋   | 8/12 [00:00<00:00, 59.41it/s, acc=13.9, loss=3.4]
# split=val:  75%|███████▌  | 9/12 [00:00<00:00, 59.41it/s, acc=13.9, loss=3.41]
# split=val:  83%|████████▎ | 10/12 [00:00<00:00, 59.41it/s, acc=13.7, loss=3.41]
# split=val:  92%|█████████▏| 11/12 [00:00<00:00, 59.41it/s, acc=13.7, loss=3.41]
# training routine:   2%|▏         | 1/50 [00:01<01:29,  1.82s/it, sample1=Irish->o, sample2=Greek->Aa]
# split=train: 100%|██████████| 60/60 [00:01<00:00, 32.99it/s, acc=8.46, loss=4.04]
#
# split=train:   0%|          | 0/60 [00:00<?, ?it/s, acc=13.2, loss=3.4]
# split=train:   2%|▏         | 1/60 [00:00<00:02, 20.41it/s, acc=13.5, loss=3.39]
# split=train:   3%|▎         | 2/60 [00:00<00:02, 26.67it/s, acc=14.3, loss=3.39]
# split=train:   5%|▌         | 3/60 [00:00<00:01, 29.70it/s, acc=13.9, loss=3.38]
# split=train:   7%|▋         | 4/60 [00:00<00:01, 39.22it/s, acc=13.9, loss=3.38]
# split=train:   7%|▋         | 4/60 [00:00<00:01, 39.22it/s, acc=14, loss=3.38]
# split=train:   8%|▊         | 5/60 [00:00<00:01, 39.22it/s, acc=14.2, loss=3.37]
# split=train:  10%|█         | 6/60 [00:00<00:01, 39.22it/s, acc=14.3, loss=3.36]
# split=train:  12%|█▏        | 7/60 [00:00<00:01, 39.22it/s, acc=14.5, loss=3.36]
# split=train:  13%|█▎        | 8/60 [00:00<00:01, 39.22it/s, acc=14.5, loss=3.35]
# split=train:  15%|█▌        | 9/60 [00:00<00:01, 41.18it/s, acc=14.5, loss=3.35]
# split=train:  15%|█▌        | 9/60 [00:00<00:01, 41.18it/s, acc=14.5, loss=3.35]
# split=train:  17%|█▋        | 10/60 [00:00<00:01, 41.18it/s, acc=14.6, loss=3.34]
# split=train:  18%|█▊        | 11/60 [00:00<00:01, 41.18it/s, acc=14.7, loss=3.34]
# split=train:  20%|██        | 12/60 [00:00<00:01, 41.18it/s, acc=14.7, loss=3.33]
# split=train:  22%|██▏       | 13/60 [00:00<00:01, 41.18it/s, acc=14.8, loss=3.33]
# split=train:  23%|██▎       | 14/60 [00:00<00:01, 40.93it/s, acc=14.8, loss=3.33]
# split=train:  23%|██▎       | 14/60 [00:00<00:01, 40.93it/s, acc=14.7, loss=3.33]
# split=train:  25%|██▌       | 15/60 [00:00<00:01, 40.93it/s, acc=14.9, loss=3.32]
# split=train:  27%|██▋       | 16/60 [00:00<00:01, 40.93it/s, acc=14.9, loss=3.32]
# split=train:  28%|██▊       | 17/60 [00:00<00:01, 40.93it/s, acc=14.9, loss=3.32]
# split=train:  30%|███       | 18/60 [00:00<00:01, 40.93it/s, acc=14.9, loss=3.31]
# split=train:  32%|███▏      | 19/60 [00:00<00:01, 40.81it/s, acc=14.9, loss=3.31]
# split=train:  32%|███▏      | 19/60 [00:00<00:01, 40.81it/s, acc=15, loss=3.31]
# split=train:  33%|███▎      | 20/60 [00:00<00:00, 40.81it/s, acc=14.9, loss=3.31]
# split=train:  35%|███▌      | 21/60 [00:00<00:00, 40.81it/s, acc=14.9, loss=3.3]
# split=train:  37%|███▋      | 22/60 [00:00<00:00, 40.81it/s, acc=14.9, loss=3.3]
# split=train:  38%|███▊      | 23/60 [00:00<00:00, 40.81it/s, acc=15, loss=3.3]
# split=train:  40%|████      | 24/60 [00:00<00:00, 41.88it/s, acc=15, loss=3.3]
# split=train:  40%|████      | 24/60 [00:00<00:00, 41.88it/s, acc=15.1, loss=3.3]
# split=train:  42%|████▏     | 25/60 [00:00<00:00, 41.88it/s, acc=15, loss=3.29]
# split=train:  43%|████▎     | 26/60 [00:00<00:00, 41.88it/s, acc=15, loss=3.29]
# split=train:  45%|████▌     | 27/60 [00:00<00:00, 41.88it/s, acc=15, loss=3.29]
# split=train:  47%|████▋     | 28/60 [00:00<00:00, 41.88it/s, acc=15, loss=3.29]
# split=train:  48%|████▊     | 29/60 [00:00<00:00, 39.86it/s, acc=15, loss=3.29]
# split=train:  48%|████▊     | 29/60 [00:00<00:00, 39.86it/s, acc=15, loss=3.28]
# split=train:  50%|█████     | 30/60 [00:00<00:00, 39.86it/s, acc=15, loss=3.28]
# split=train:  52%|█████▏    | 31/60 [00:00<00:00, 39.86it/s, acc=15.1, loss=3.28]
# split=train:  53%|█████▎    | 32/60 [00:00<00:00, 39.86it/s, acc=15.1, loss=3.27]
# split=train:  55%|█████▌    | 33/60 [00:00<00:00, 39.86it/s, acc=15.1, loss=3.27]
# split=train:  57%|█████▋    | 34/60 [00:00<00:00, 39.59it/s, acc=15.1, loss=3.27]
# split=train:  57%|█████▋    | 34/60 [00:00<00:00, 39.59it/s, acc=15.1, loss=3.27]
# split=train:  58%|█████▊    | 35/60 [00:00<00:00, 39.59it/s, acc=15.2, loss=3.27]
# split=train:  60%|██████    | 36/60 [00:00<00:00, 39.59it/s, acc=15.2, loss=3.26]
# split=train:  62%|██████▏   | 37/60 [00:00<00:00, 39.59it/s, acc=15.2, loss=3.26]
# split=train:  63%|██████▎   | 38/60 [00:00<00:00, 39.59it/s, acc=15.3, loss=3.26]
# split=train:  65%|██████▌   | 39/60 [00:00<00:00, 40.03it/s, acc=15.3, loss=3.26]
# split=train:  65%|██████▌   | 39/60 [00:00<00:00, 40.03it/s, acc=15.3, loss=3.26]
# split=train:  67%|██████▋   | 40/60 [00:01<00:00, 40.03it/s, acc=15.3, loss=3.26]
# split=train:  68%|██████▊   | 41/60 [00:01<00:00, 40.03it/s, acc=15.3, loss=3.25]
# split=train:  70%|███████   | 42/60 [00:01<00:00, 40.03it/s, acc=15.2, loss=3.25]
# split=train:  72%|███████▏  | 43/60 [00:01<00:00, 40.03it/s, acc=15.3, loss=3.25]
# split=train:  73%|███████▎  | 44/60 [00:01<00:00, 40.02it/s, acc=15.3, loss=3.25]
# split=train:  73%|███████▎  | 44/60 [00:01<00:00, 40.02it/s, acc=15.3, loss=3.25]
# split=train:  75%|███████▌  | 45/60 [00:01<00:00, 40.02it/s, acc=15.4, loss=3.24]
# split=train:  77%|███████▋  | 46/60 [00:01<00:00, 40.02it/s, acc=15.4, loss=3.24]
# split=train:  78%|███████▊  | 47/60 [00:01<00:00, 40.02it/s, acc=15.4, loss=3.24]
# split=train:  80%|████████  | 48/60 [00:01<00:00, 40.02it/s, acc=15.4, loss=3.24]
# split=train:  82%|████████▏ | 49/60 [00:01<00:00, 40.51it/s, acc=15.4, loss=3.24]
# split=train:  82%|████████▏ | 49/60 [00:01<00:00, 40.51it/s, acc=15.4, loss=3.24]
# split=train:  83%|████████▎ | 50/60 [00:01<00:00, 40.51it/s, acc=15.5, loss=3.23]
# split=train:  85%|████████▌ | 51/60 [00:01<00:00, 40.51it/s, acc=15.5, loss=3.23]
# split=train:  87%|████████▋ | 52/60 [00:01<00:00, 40.51it/s, acc=15.5, loss=3.23]
# split=train:  88%|████████▊ | 53/60 [00:01<00:00, 40.51it/s, acc=15.5, loss=3.23]
# split=train:  90%|█████████ | 54/60 [00:01<00:00, 40.26it/s, acc=15.5, loss=3.23]
# split=train:  90%|█████████ | 54/60 [00:01<00:00, 40.26it/s, acc=15.5, loss=3.23]
# split=train:  92%|█████████▏| 55/60 [00:01<00:00, 40.26it/s, acc=15.6, loss=3.22]
# split=train:  93%|█████████▎| 56/60 [00:01<00:00, 40.26it/s, acc=15.6, loss=3.22]
# split=train:  95%|█████████▌| 57/60 [00:01<00:00, 40.26it/s, acc=15.6, loss=3.22]
# split=train:  97%|█████████▋| 58/60 [00:01<00:00, 40.26it/s, acc=15.7, loss=3.22]
# split=train:  98%|█████████▊| 59/60 [00:01<00:00, 40.15it/s, acc=15.7, loss=3.22]
# split=train:  98%|█████████▊| 59/60 [00:01<00:00, 40.15it/s, acc=15.7, loss=3.22]
# split=val: 100%|██████████| 12/12 [00:01<00:00,  7.05it/s, acc=13.7, loss=3.41]
#
# split=val:   0%|          | 0/12 [00:00<?, ?it/s, acc=18.5, loss=3.11]
# split=val:   8%|▊         | 1/12 [00:00<00:00, 31.25it/s, acc=17.4, loss=3.09]
# split=val:  17%|█▋        | 2/12 [00:00<00:00, 41.67it/s, acc=17.5, loss=3.09]
# split=val:  25%|██▌       | 3/12 [00:00<00:00, 46.87it/s, acc=17.2, loss=3.09]
# split=val:  33%|███▎      | 4/12 [00:00<00:00, 49.99it/s, acc=17.3, loss=3.09]
# split=val:  42%|████▏     | 5/12 [00:00<00:00, 52.08it/s, acc=17.3, loss=3.09]
# split=val:  50%|█████     | 6/12 [00:00<00:00, 53.57it/s, acc=17.4, loss=3.09]
# split=val:  58%|█████▊    | 7/12 [00:00<00:00, 61.95it/s, acc=17.4, loss=3.09]
# split=val:  58%|█████▊    | 7/12 [00:00<00:00, 61.95it/s, acc=17.3, loss=3.09]
# split=val:  67%|██████▋   | 8/12 [00:00<00:00, 61.95it/s, acc=17.2, loss=3.09]
# split=val:  75%|███████▌  | 9/12 [00:00<00:00, 61.95it/s, acc=17.3, loss=3.09]
# split=val:  83%|████████▎ | 10/12 [00:00<00:00, 61.95it/s, acc=17.3, loss=3.09]
# training routine:   4%|▍         | 2/50 [00:03<01:23,  1.75s/it, sample1=Greek->uaar, sample2=Irish->ŚUaKsohr]
# split=train: 100%|██████████| 60/60 [00:01<00:00, 35.35it/s, acc=15.7, loss=3.22]
#
# split=train:   0%|          | 0/60 [00:00<?, ?it/s, acc=18.8, loss=3.08]
# split=train:   2%|▏         | 1/60 [00:00<00:02, 20.41it/s, acc=18.2, loss=3.08]
# split=train:   3%|▎         | 2/60 [00:00<00:02, 28.57it/s, acc=17.9, loss=3.09]
# split=train:   5%|▌         | 3/60 [00:00<00:01, 32.61it/s, acc=18.3, loss=3.08]
# split=train:   7%|▋         | 4/60 [00:00<00:01, 35.09it/s, acc=18.3, loss=3.09]
# split=train:   8%|▊         | 5/60 [00:00<00:01, 43.48it/s, acc=18.3, loss=3.09]
# split=train:   8%|▊         | 5/60 [00:00<00:01, 43.48it/s, acc=18.4, loss=3.09]
# split=train:  10%|█         | 6/60 [00:00<00:01, 43.48it/s, acc=18.2, loss=3.09]
# split=train:  12%|█▏        | 7/60 [00:00<00:01, 43.48it/s, acc=18.1, loss=3.09]
# split=train:  13%|█▎        | 8/60 [00:00<00:01, 43.48it/s, acc=17.9, loss=3.08]
# split=train:  15%|█▌        | 9/60 [00:00<00:01, 43.48it/s, acc=17.9, loss=3.08]
# split=train:  17%|█▋        | 10/60 [00:00<00:01, 42.82it/s, acc=17.9, loss=3.08]
# split=train:  17%|█▋        | 10/60 [00:00<00:01, 42.82it/s, acc=17.8, loss=3.08]
# split=train:  18%|█▊        | 11/60 [00:00<00:01, 42.82it/s, acc=17.9, loss=3.08]
# split=train:  20%|██        | 12/60 [00:00<00:01, 42.82it/s, acc=17.9, loss=3.07]
# split=train:  22%|██▏       | 13/60 [00:00<00:01, 42.82it/s, acc=18, loss=3.07]
# split=train:  23%|██▎       | 14/60 [00:00<00:01, 42.82it/s, acc=18, loss=3.07]
# split=train:  25%|██▌       | 15/60 [00:00<00:01, 41.64it/s, acc=18, loss=3.07]
# split=train:  25%|██▌       | 15/60 [00:00<00:01, 41.64it/s, acc=18, loss=3.07]
# split=train:  27%|██▋       | 16/60 [00:00<00:01, 41.64it/s, acc=18, loss=3.07]
# split=train:  28%|██▊       | 17/60 [00:00<00:01, 41.64it/s, acc=18.1, loss=3.07]
# split=train:  30%|███       | 18/60 [00:00<00:01, 41.64it/s, acc=18, loss=3.07]
# split=train:  32%|███▏      | 19/60 [00:00<00:00, 41.64it/s, acc=18, loss=3.07]
# split=train:  33%|███▎      | 20/60 [00:00<00:00, 43.22it/s, acc=18, loss=3.07]
# split=train:  33%|███▎      | 20/60 [00:00<00:00, 43.22it/s, acc=18, loss=3.06]
# split=train:  35%|███▌      | 21/60 [00:00<00:00, 43.22it/s, acc=18, loss=3.06]
# split=train:  37%|███▋      | 22/60 [00:00<00:00, 43.22it/s, acc=18, loss=3.06]
# split=train:  38%|███▊      | 23/60 [00:00<00:00, 43.22it/s, acc=18, loss=3.06]
# split=train:  40%|████      | 24/60 [00:00<00:00, 43.22it/s, acc=18, loss=3.06]
# split=train:  42%|████▏     | 25/60 [00:00<00:00, 41.13it/s, acc=18, loss=3.06]
# split=train:  42%|████▏     | 25/60 [00:00<00:00, 41.13it/s, acc=18, loss=3.06]
# split=train:  43%|████▎     | 26/60 [00:00<00:00, 41.13it/s, acc=18, loss=3.06]
# split=train:  45%|████▌     | 27/60 [00:00<00:00, 41.13it/s, acc=18, loss=3.06]
# split=train:  47%|████▋     | 28/60 [00:00<00:00, 41.13it/s, acc=18, loss=3.06]
# split=train:  48%|████▊     | 29/60 [00:00<00:00, 41.13it/s, acc=18, loss=3.06]
# split=train:  50%|█████     | 30/60 [00:00<00:00, 40.51it/s, acc=18, loss=3.06]
# split=train:  50%|█████     | 30/60 [00:00<00:00, 40.51it/s, acc=18, loss=3.05]
# split=train:  52%|█████▏    | 31/60 [00:00<00:00, 40.51it/s, acc=18, loss=3.05]
# split=train:  53%|█████▎    | 32/60 [00:00<00:00, 40.51it/s, acc=18, loss=3.05]
# split=train:  55%|█████▌    | 33/60 [00:00<00:00, 40.51it/s, acc=18, loss=3.05]
# split=train:  57%|█████▋    | 34/60 [00:00<00:00, 40.51it/s, acc=18, loss=3.05]
# split=train:  58%|█████▊    | 35/60 [00:00<00:00, 40.45it/s, acc=18, loss=3.05]
# split=train:  58%|█████▊    | 35/60 [00:00<00:00, 40.45it/s, acc=18, loss=3.05]
# split=train:  60%|██████    | 36/60 [00:00<00:00, 40.45it/s, acc=18, loss=3.05]
# split=train:  62%|██████▏   | 37/60 [00:00<00:00, 40.45it/s, acc=18, loss=3.05]
# split=train:  63%|██████▎   | 38/60 [00:00<00:00, 40.45it/s, acc=18, loss=3.05]
# split=train:  65%|██████▌   | 39/60 [00:00<00:00, 40.45it/s, acc=18.1, loss=3.05]
# split=train:  67%|██████▋   | 40/60 [00:00<00:00, 40.72it/s, acc=18.1, loss=3.05]
# split=train:  67%|██████▋   | 40/60 [00:00<00:00, 40.72it/s, acc=18.1, loss=3.04]
# split=train:  68%|██████▊   | 41/60 [00:01<00:00, 40.72it/s, acc=18.1, loss=3.04]
# split=train:  70%|███████   | 42/60 [00:01<00:00, 40.72it/s, acc=18.1, loss=3.04]
# split=train:  72%|███████▏  | 43/60 [00:01<00:00, 40.72it/s, acc=18.1, loss=3.04]
# split=train:  73%|███████▎  | 44/60 [00:01<00:00, 40.72it/s, acc=18.2, loss=3.04]
# split=train:  75%|███████▌  | 45/60 [00:01<00:00, 39.69it/s, acc=18.2, loss=3.04]
# split=train:  75%|███████▌  | 45/60 [00:01<00:00, 39.69it/s, acc=18.2, loss=3.04]
# split=train:  77%|███████▋  | 46/60 [00:01<00:00, 39.69it/s, acc=18.2, loss=3.04]
# split=train:  78%|███████▊  | 47/60 [00:01<00:00, 39.69it/s, acc=18.2, loss=3.04]
# split=train:  80%|████████  | 48/60 [00:01<00:00, 39.69it/s, acc=18.2, loss=3.03]
# split=train:  82%|████████▏ | 49/60 [00:01<00:00, 39.26it/s, acc=18.2, loss=3.03]
# split=train:  82%|████████▏ | 49/60 [00:01<00:00, 39.26it/s, acc=18.2, loss=3.03]
# split=train:  83%|████████▎ | 50/60 [00:01<00:00, 39.26it/s, acc=18.2, loss=3.03]
# split=train:  85%|████████▌ | 51/60 [00:01<00:00, 39.26it/s, acc=18.2, loss=3.03]
# split=train:  87%|████████▋ | 52/60 [00:01<00:00, 39.26it/s, acc=18.2, loss=3.03]
# split=train:  88%|████████▊ | 53/60 [00:01<00:00, 37.92it/s, acc=18.2, loss=3.03]
# split=train:  88%|████████▊ | 53/60 [00:01<00:00, 37.92it/s, acc=18.2, loss=3.03]
# split=train:  90%|█████████ | 54/60 [00:01<00:00, 37.92it/s, acc=18.2, loss=3.03]
# split=train:  92%|█████████▏| 55/60 [00:01<00:00, 37.92it/s, acc=18.3, loss=3.03]
# split=train:  93%|█████████▎| 56/60 [00:01<00:00, 37.92it/s, acc=18.3, loss=3.02]
# split=train:  95%|█████████▌| 57/60 [00:01<00:00, 38.18it/s, acc=18.3, loss=3.02]
# split=train:  95%|█████████▌| 57/60 [00:01<00:00, 38.18it/s, acc=18.3, loss=3.02]
# split=train:  97%|█████████▋| 58/60 [00:01<00:00, 38.18it/s, acc=18.3, loss=3.02]
# split=train:  98%|█████████▊| 59/60 [00:01<00:00, 38.18it/s, acc=18.3, loss=3.02]
# split=val: 100%|██████████| 12/12 [00:01<00:00,  6.98it/s, acc=17.4, loss=3.09]
#
# split=val:   0%|          | 0/12 [00:00<?, ?it/s, acc=20.1, loss=2.96]
# split=val:   8%|▊         | 1/12 [00:00<00:00, 31.26it/s, acc=19.1, loss=2.96]
# split=val:  17%|█▋        | 2/12 [00:00<00:00, 40.81it/s, acc=19.5, loss=2.96]
# split=val:  25%|██▌       | 3/12 [00:00<00:00, 46.16it/s, acc=19.4, loss=2.96]
# split=val:  33%|███▎      | 4/12 [00:00<00:00, 48.78it/s, acc=19.8, loss=2.95]
# split=val:  42%|████▏     | 5/12 [00:00<00:00, 51.02it/s, acc=19.8, loss=2.95]
# split=val:  50%|█████     | 6/12 [00:00<00:00, 52.63it/s, acc=19.8, loss=2.95]
# split=val:  58%|█████▊    | 7/12 [00:00<00:00, 60.87it/s, acc=19.8, loss=2.95]
# split=val:  58%|█████▊    | 7/12 [00:00<00:00, 60.87it/s, acc=19.6, loss=2.95]
# split=val:  67%|██████▋   | 8/12 [00:00<00:00, 60.87it/s, acc=19.6, loss=2.95]
# split=val:  75%|███████▌  | 9/12 [00:00<00:00, 60.87it/s, acc=19.5, loss=2.95]
# split=val:  83%|████████▎ | 10/12 [00:00<00:00, 60.87it/s, acc=19.5, loss=2.95]
# training routine:   6%|▌         | 3/50 [00:05<01:21,  1.73s/it, sample1=Italian->Aniv, sample2=German->Maey]
# split=train: 100%|██████████| 60/60 [00:01<00:00, 35.01it/s, acc=18.3, loss=3.02]
#
# split=train:   0%|          | 0/60 [00:00<?, ?it/s, acc=19.5, loss=2.99]
# split=train:   2%|▏         | 1/60 [00:00<00:03, 15.86it/s, acc=19.2, loss=2.98]
# split=train:   3%|▎         | 2/60 [00:00<00:02, 22.99it/s, acc=19.7, loss=2.96]
# split=train:   5%|▌         | 3/60 [00:00<00:02, 27.52it/s, acc=19.7, loss=2.96]
# split=train:   7%|▋         | 4/60 [00:00<00:01, 36.36it/s, acc=19.7, loss=2.96]
# split=train:   7%|▋         | 4/60 [00:00<00:01, 36.36it/s, acc=19.7, loss=2.96]
# split=train:   8%|▊         | 5/60 [00:00<00:01, 36.36it/s, acc=19.4, loss=2.96]
# split=train:  10%|█         | 6/60 [00:00<00:01, 36.36it/s, acc=19.3, loss=2.96]
# split=train:  12%|█▏        | 7/60 [00:00<00:01, 36.36it/s, acc=19.3, loss=2.96]
# split=train:  13%|█▎        | 8/60 [00:00<00:01, 35.79it/s, acc=19.3, loss=2.96]
# split=train:  13%|█▎        | 8/60 [00:00<00:01, 35.79it/s, acc=19.4, loss=2.96]
# split=train:  15%|█▌        | 9/60 [00:00<00:01, 35.79it/s, acc=19.3, loss=2.95]
# split=train:  17%|█▋        | 10/60 [00:00<00:01, 35.79it/s, acc=19.3, loss=2.95]
# split=train:  18%|█▊        | 11/60 [00:00<00:01, 35.79it/s, acc=19.2, loss=2.95]
# split=train:  20%|██        | 12/60 [00:00<00:01, 35.79it/s, acc=19.1, loss=2.95]
# split=train:  22%|██▏       | 13/60 [00:00<00:01, 39.68it/s, acc=19.1, loss=2.95]
# split=train:  22%|██▏       | 13/60 [00:00<00:01, 39.68it/s, acc=19.1, loss=2.95]
# split=train:  23%|██▎       | 14/60 [00:00<00:01, 39.68it/s, acc=19.1, loss=2.95]
# split=train:  25%|██▌       | 15/60 [00:00<00:01, 39.68it/s, acc=19.1, loss=2.95]
# split=train:  27%|██▋       | 16/60 [00:00<00:01, 39.68it/s, acc=19, loss=2.95]
# split=train:  28%|██▊       | 17/60 [00:00<00:01, 39.68it/s, acc=19, loss=2.94]
# split=train:  30%|███       | 18/60 [00:00<00:01, 39.94it/s, acc=19, loss=2.94]
# split=train:  30%|███       | 18/60 [00:00<00:01, 39.94it/s, acc=19.1, loss=2.94]
# split=train:  32%|███▏      | 19/60 [00:00<00:01, 39.94it/s, acc=19.1, loss=2.94]
# split=train:  33%|███▎      | 20/60 [00:00<00:01, 39.94it/s, acc=19.1, loss=2.94]
# split=train:  35%|███▌      | 21/60 [00:00<00:00, 39.94it/s, acc=19.1, loss=2.94]
# split=train:  37%|███▋      | 22/60 [00:00<00:00, 39.94it/s, acc=19.1, loss=2.94]
# split=train:  38%|███▊      | 23/60 [00:00<00:00, 39.03it/s, acc=19.1, loss=2.94]
# split=train:  38%|███▊      | 23/60 [00:00<00:00, 39.03it/s, acc=19.2, loss=2.94]
# split=train:  40%|████      | 24/60 [00:00<00:00, 39.03it/s, acc=19.2, loss=2.93]
# split=train:  42%|████▏     | 25/60 [00:00<00:00, 39.03it/s, acc=19.1, loss=2.93]
# split=train:  43%|████▎     | 26/60 [00:00<00:00, 39.03it/s, acc=19.2, loss=2.93]
# split=train:  45%|████▌     | 27/60 [00:00<00:00, 37.54it/s, acc=19.2, loss=2.93]
# split=train:  45%|████▌     | 27/60 [00:00<00:00, 37.54it/s, acc=19.2, loss=2.93]
# split=train:  47%|████▋     | 28/60 [00:00<00:00, 37.54it/s, acc=19.2, loss=2.93]
# split=train:  48%|████▊     | 29/60 [00:00<00:00, 37.54it/s, acc=19.2, loss=2.93]
# split=train:  50%|█████     | 30/60 [00:00<00:00, 37.54it/s, acc=19.3, loss=2.93]
# split=train:  52%|█████▏    | 31/60 [00:00<00:00, 38.03it/s, acc=19.3, loss=2.93]
# split=train:  52%|█████▏    | 31/60 [00:00<00:00, 38.03it/s, acc=19.3, loss=2.93]
# split=train:  53%|█████▎    | 32/60 [00:00<00:00, 38.03it/s, acc=19.2, loss=2.93]
# split=train:  55%|█████▌    | 33/60 [00:00<00:00, 38.03it/s, acc=19.2, loss=2.92]
# split=train:  57%|█████▋    | 34/60 [00:00<00:00, 38.03it/s, acc=19.3, loss=2.92]
# split=train:  58%|█████▊    | 35/60 [00:00<00:00, 38.03it/s, acc=19.3, loss=2.92]
# split=train:  60%|██████    | 36/60 [00:00<00:00, 39.01it/s, acc=19.3, loss=2.92]
# split=train:  60%|██████    | 36/60 [00:00<00:00, 39.01it/s, acc=19.4, loss=2.92]
# split=train:  62%|██████▏   | 37/60 [00:00<00:00, 39.01it/s, acc=19.4, loss=2.92]
# split=train:  63%|██████▎   | 38/60 [00:01<00:00, 39.01it/s, acc=19.5, loss=2.92]
# split=train:  65%|██████▌   | 39/60 [00:01<00:00, 39.01it/s, acc=19.5, loss=2.92]
# split=train:  67%|██████▋   | 40/60 [00:01<00:00, 39.01it/s, acc=19.5, loss=2.92]
# split=train:  68%|██████▊   | 41/60 [00:01<00:00, 40.07it/s, acc=19.5, loss=2.92]
# split=train:  68%|██████▊   | 41/60 [00:01<00:00, 40.07it/s, acc=19.5, loss=2.91]
# split=train:  70%|███████   | 42/60 [00:01<00:00, 40.07it/s, acc=19.6, loss=2.91]
# split=train:  72%|███████▏  | 43/60 [00:01<00:00, 40.07it/s, acc=19.6, loss=2.91]
# split=train:  73%|███████▎  | 44/60 [00:01<00:00, 40.07it/s, acc=19.5, loss=2.91]
# split=train:  75%|███████▌  | 45/60 [00:01<00:00, 40.07it/s, acc=19.5, loss=2.91]
# split=train:  77%|███████▋  | 46/60 [00:01<00:00, 40.15it/s, acc=19.5, loss=2.91]
# split=train:  77%|███████▋  | 46/60 [00:01<00:00, 40.15it/s, acc=19.5, loss=2.91]
# split=train:  78%|███████▊  | 47/60 [00:01<00:00, 40.15it/s, acc=19.6, loss=2.91]
# split=train:  80%|████████  | 48/60 [00:01<00:00, 40.15it/s, acc=19.6, loss=2.91]
# split=train:  82%|████████▏ | 49/60 [00:01<00:00, 40.15it/s, acc=19.6, loss=2.91]
# split=train:  83%|████████▎ | 50/60 [00:01<00:00, 40.15it/s, acc=19.7, loss=2.91]
# split=train:  85%|████████▌ | 51/60 [00:01<00:00, 40.31it/s, acc=19.7, loss=2.91]
# split=train:  85%|████████▌ | 51/60 [00:01<00:00, 40.31it/s, acc=19.7, loss=2.91]
# split=train:  87%|████████▋ | 52/60 [00:01<00:00, 40.31it/s, acc=19.7, loss=2.9]
# split=train:  88%|████████▊ | 53/60 [00:01<00:00, 40.31it/s, acc=19.7, loss=2.9]
# split=train:  90%|█████████ | 54/60 [00:01<00:00, 40.31it/s, acc=19.8, loss=2.9]
# split=train:  92%|█████████▏| 55/60 [00:01<00:00, 40.31it/s, acc=19.8, loss=2.9]
# split=train:  93%|█████████▎| 56/60 [00:01<00:00, 40.62it/s, acc=19.8, loss=2.9]
# split=train:  93%|█████████▎| 56/60 [00:01<00:00, 40.62it/s, acc=19.8, loss=2.9]
# split=train:  95%|█████████▌| 57/60 [00:01<00:00, 40.62it/s, acc=19.8, loss=2.9]
# split=train:  97%|█████████▋| 58/60 [00:01<00:00, 40.62it/s, acc=19.8, loss=2.9]
# split=train:  98%|█████████▊| 59/60 [00:01<00:00, 40.62it/s, acc=19.8, loss=2.9]
# split=val: 100%|██████████| 12/12 [00:01<00:00,  6.93it/s, acc=19.5, loss=2.95]
#
# split=val:   0%|          | 0/12 [00:00<?, ?it/s, acc=21.6, loss=2.85]
# split=val:   8%|▊         | 1/12 [00:00<00:00, 32.26it/s, acc=21.1, loss=2.84]
# split=val:  17%|█▋        | 2/12 [00:00<00:00, 41.67it/s, acc=21.2, loss=2.85]
# split=val:  25%|██▌       | 3/12 [00:00<00:00, 44.78it/s, acc=21.1, loss=2.84]
# split=val:  33%|███▎      | 4/12 [00:00<00:00, 48.19it/s, acc=21, loss=2.84]
# split=val:  42%|████▏     | 5/12 [00:00<00:00, 50.50it/s, acc=20.9, loss=2.85]
# split=val:  50%|█████     | 6/12 [00:00<00:00, 59.99it/s, acc=20.9, loss=2.85]
# split=val:  50%|█████     | 6/12 [00:00<00:00, 59.99it/s, acc=21, loss=2.85]
# split=val:  58%|█████▊    | 7/12 [00:00<00:00, 59.99it/s, acc=21, loss=2.85]
# split=val:  67%|██████▋   | 8/12 [00:00<00:00, 59.99it/s, acc=20.9, loss=2.84]
# split=val:  75%|███████▌  | 9/12 [00:00<00:00, 59.99it/s, acc=20.9, loss=2.85]
# split=val:  83%|████████▎ | 10/12 [00:00<00:00, 59.99it/s, acc=20.9, loss=2.85]
# training routine:   8%|▊         | 4/50 [00:06<01:19,  1.73s/it, sample1=Chinese->Desra, sample2=German->Kan]
# split=train: 100%|██████████| 60/60 [00:01<00:00, 34.66it/s, acc=19.8, loss=2.9]
#
# split=train:   0%|          | 0/60 [00:00<?, ?it/s, acc=20.8, loss=2.87]
# split=train:   2%|▏         | 1/60 [00:00<00:04, 12.99it/s, acc=20.7, loss=2.87]
# split=train:   3%|▎         | 2/60 [00:00<00:03, 18.51it/s, acc=20.9, loss=2.85]
# split=train:   5%|▌         | 3/60 [00:00<00:02, 27.52it/s, acc=20.9, loss=2.85]
# split=train:   5%|▌         | 3/60 [00:00<00:02, 27.52it/s, acc=20.9, loss=2.84]
# split=train:   7%|▋         | 4/60 [00:00<00:02, 27.52it/s, acc=20.8, loss=2.84]
# split=train:   8%|▊         | 5/60 [00:00<00:01, 27.52it/s, acc=20.5, loss=2.85]
# split=train:  10%|█         | 6/60 [00:00<00:01, 27.52it/s, acc=21, loss=2.84]
# split=train:  12%|█▏        | 7/60 [00:00<00:01, 32.23it/s, acc=21, loss=2.84]
# split=train:  12%|█▏        | 7/60 [00:00<00:01, 32.23it/s, acc=21, loss=2.84]
# split=train:  13%|█▎        | 8/60 [00:00<00:01, 32.23it/s, acc=21, loss=2.84]
# split=train:  15%|█▌        | 9/60 [00:00<00:01, 32.23it/s, acc=21.1, loss=2.84]
# split=train:  17%|█▋        | 10/60 [00:00<00:01, 32.23it/s, acc=21, loss=2.84]
# split=train:  18%|█▊        | 11/60 [00:00<00:01, 33.41it/s, acc=21, loss=2.84]
# split=train:  18%|█▊        | 11/60 [00:00<00:01, 33.41it/s, acc=21.2, loss=2.83]
# split=train:  20%|██        | 12/60 [00:00<00:01, 33.41it/s, acc=21.1, loss=2.84]
# split=train:  22%|██▏       | 13/60 [00:00<00:01, 33.41it/s, acc=21.2, loss=2.83]
# split=train:  23%|██▎       | 14/60 [00:00<00:01, 33.41it/s, acc=21.2, loss=2.83]
# split=train:  25%|██▌       | 15/60 [00:00<00:01, 33.41it/s, acc=21.1, loss=2.83]
# split=train:  27%|██▋       | 16/60 [00:00<00:01, 36.54it/s, acc=21.1, loss=2.83]
# split=train:  27%|██▋       | 16/60 [00:00<00:01, 36.54it/s, acc=21.2, loss=2.83]
# split=train:  28%|██▊       | 17/60 [00:00<00:01, 36.54it/s, acc=21.2, loss=2.83]
# split=train:  30%|███       | 18/60 [00:00<00:01, 36.54it/s, acc=21.1, loss=2.83]
# split=train:  32%|███▏      | 19/60 [00:00<00:01, 36.54it/s, acc=21.2, loss=2.83]
# split=train:  33%|███▎      | 20/60 [00:00<00:01, 36.13it/s, acc=21.2, loss=2.83]
# split=train:  33%|███▎      | 20/60 [00:00<00:01, 36.13it/s, acc=21.1, loss=2.83]
# split=train:  35%|███▌      | 21/60 [00:00<00:01, 36.13it/s, acc=21.1, loss=2.83]
# split=train:  37%|███▋      | 22/60 [00:00<00:01, 36.13it/s, acc=21.1, loss=2.83]
# split=train:  38%|███▊      | 23/60 [00:00<00:01, 36.13it/s, acc=21.1, loss=2.83]
# split=train:  40%|████      | 24/60 [00:00<00:00, 36.13it/s, acc=21.1, loss=2.83]
# split=train:  42%|████▏     | 25/60 [00:00<00:00, 38.40it/s, acc=21.1, loss=2.83]
# split=train:  42%|████▏     | 25/60 [00:00<00:00, 38.40it/s, acc=21.1, loss=2.83]
# split=train:  43%|████▎     | 26/60 [00:00<00:00, 38.40it/s, acc=21.1, loss=2.82]
# split=train:  45%|████▌     | 27/60 [00:00<00:00, 38.40it/s, acc=21, loss=2.82]
# split=train:  47%|████▋     | 28/60 [00:00<00:00, 38.40it/s, acc=21.1, loss=2.82]
# split=train:  48%|████▊     | 29/60 [00:00<00:00, 38.40it/s, acc=21.1, loss=2.82]
# split=train:  50%|█████     | 30/60 [00:00<00:00, 39.17it/s, acc=21.1, loss=2.82]
# split=train:  50%|█████     | 30/60 [00:00<00:00, 39.17it/s, acc=21.2, loss=2.82]
# split=train:  52%|█████▏    | 31/60 [00:00<00:00, 39.17it/s, acc=21.2, loss=2.82]
# split=train:  53%|█████▎    | 32/60 [00:00<00:00, 39.17it/s, acc=21.2, loss=2.82]
# split=train:  55%|█████▌    | 33/60 [00:00<00:00, 39.17it/s, acc=21.2, loss=2.82]
# split=train:  57%|█████▋    | 34/60 [00:00<00:00, 39.17it/s, acc=21.2, loss=2.82]
# split=train:  58%|█████▊    | 35/60 [00:00<00:00, 39.03it/s, acc=21.2, loss=2.82]
# split=train:  58%|█████▊    | 35/60 [00:00<00:00, 39.03it/s, acc=21.3, loss=2.81]
# split=train:  60%|██████    | 36/60 [00:00<00:00, 39.03it/s, acc=21.4, loss=2.81]
# split=train:  62%|██████▏   | 37/60 [00:01<00:00, 39.03it/s, acc=21.4, loss=2.81]
# split=train:  63%|██████▎   | 38/60 [00:01<00:00, 39.03it/s, acc=21.4, loss=2.81]
# split=train:  65%|██████▌   | 39/60 [00:01<00:00, 39.03it/s, acc=21.5, loss=2.81]
# split=train:  67%|██████▋   | 40/60 [00:01<00:00, 40.36it/s, acc=21.5, loss=2.81]
# split=train:  67%|██████▋   | 40/60 [00:01<00:00, 40.36it/s, acc=21.4, loss=2.81]
# split=train:  68%|██████▊   | 41/60 [00:01<00:00, 40.36it/s, acc=21.4, loss=2.81]
# split=train:  70%|███████   | 42/60 [00:01<00:00, 40.36it/s, acc=21.5, loss=2.81]
# split=train:  72%|███████▏  | 43/60 [00:01<00:00, 40.36it/s, acc=21.5, loss=2.81]
# split=train:  73%|███████▎  | 44/60 [00:01<00:00, 40.36it/s, acc=21.4, loss=2.81]
# split=train:  75%|███████▌  | 45/60 [00:01<00:00, 40.25it/s, acc=21.4, loss=2.81]
# split=train:  75%|███████▌  | 45/60 [00:01<00:00, 40.25it/s, acc=21.4, loss=2.81]
# split=train:  77%|███████▋  | 46/60 [00:01<00:00, 40.25it/s, acc=21.5, loss=2.81]
# split=train:  78%|███████▊  | 47/60 [00:01<00:00, 40.25it/s, acc=21.4, loss=2.81]
# split=train:  80%|████████  | 48/60 [00:01<00:00, 40.25it/s, acc=21.5, loss=2.81]
# split=train:  82%|████████▏ | 49/60 [00:01<00:00, 40.25it/s, acc=21.5, loss=2.8]
# split=train:  83%|████████▎ | 50/60 [00:01<00:00, 40.68it/s, acc=21.5, loss=2.8]
# split=train:  83%|████████▎ | 50/60 [00:01<00:00, 40.68it/s, acc=21.5, loss=2.8]
# split=train:  85%|████████▌ | 51/60 [00:01<00:00, 40.68it/s, acc=21.5, loss=2.8]
# split=train:  87%|████████▋ | 52/60 [00:01<00:00, 40.68it/s, acc=21.5, loss=2.8]
# split=train:  88%|████████▊ | 53/60 [00:01<00:00, 40.68it/s, acc=21.5, loss=2.8]
# split=train:  90%|█████████ | 54/60 [00:01<00:00, 40.68it/s, acc=21.5, loss=2.8]
# split=train:  92%|█████████▏| 55/60 [00:01<00:00, 40.37it/s, acc=21.5, loss=2.8]
# split=train:  92%|█████████▏| 55/60 [00:01<00:00, 40.37it/s, acc=21.5, loss=2.8]
# split=train:  93%|█████████▎| 56/60 [00:01<00:00, 40.37it/s, acc=21.5, loss=2.8]
# split=train:  95%|█████████▌| 57/60 [00:01<00:00, 40.37it/s, acc=21.5, loss=2.8]
# split=train:  97%|█████████▋| 58/60 [00:01<00:00, 40.37it/s, acc=21.5, loss=2.8]
# split=train:  98%|█████████▊| 59/60 [00:01<00:00, 40.37it/s, acc=21.5, loss=2.8]
# split=train: 100%|██████████| 60/60 [00:01<00:00, 39.48it/s, acc=21.5, loss=2.8]
# split=val: 100%|██████████| 12/12 [00:01<00:00,  6.79it/s, acc=20.8, loss=2.85]
#
# split=val:   0%|          | 0/12 [00:00<?, ?it/s, acc=21.9, loss=2.71]
# split=val:   8%|▊         | 1/12 [00:00<00:00, 31.24it/s, acc=22.4, loss=2.72]
# split=val:  17%|█▋        | 2/12 [00:00<00:00, 41.67it/s, acc=22.1, loss=2.74]
# split=val:  25%|██▌       | 3/12 [00:00<00:00, 46.15it/s, acc=22, loss=2.76]
# split=val:  33%|███▎      | 4/12 [00:00<00:00, 48.78it/s, acc=21.9, loss=2.76]
# split=val:  42%|████▏     | 5/12 [00:00<00:00, 51.02it/s, acc=21.7, loss=2.77]
# split=val:  50%|█████     | 6/12 [00:00<00:00, 52.63it/s, acc=21.7, loss=2.77]
# split=val:  58%|█████▊    | 7/12 [00:00<00:00, 60.87it/s, acc=21.7, loss=2.77]
# split=val:  58%|█████▊    | 7/12 [00:00<00:00, 60.87it/s, acc=21.6, loss=2.77]
# split=val:  67%|██████▋   | 8/12 [00:00<00:00, 60.87it/s, acc=21.7, loss=2.77]
# split=val:  75%|███████▌  | 9/12 [00:00<00:00, 60.87it/s, acc=21.8, loss=2.77]
# split=val:  83%|████████▎ | 10/12 [00:00<00:00, 60.87it/s, acc=21.8, loss=2.76]
# training routine:  10%|█         | 5/50 [00:08<01:18,  1.75s/it, sample1=Czech->Wov, sample2=Italian->Oeserk]
# split=train: 100%|██████████| 60/60 [00:01<00:00, 33.90it/s, acc=21.5, loss=2.8]
#
# split=train:   0%|          | 0/60 [00:00<?, ?it/s, acc=21.9, loss=2.77]
# split=train:   2%|▏         | 1/60 [00:00<00:02, 20.83it/s, acc=21.1, loss=2.77]
# split=train:   3%|▎         | 2/60 [00:00<00:02, 27.39it/s, acc=21, loss=2.77]
# split=train:   5%|▌         | 3/60 [00:00<00:01, 30.61it/s, acc=20.9, loss=2.77]
# split=train:   7%|▋         | 4/60 [00:00<00:01, 33.33it/s, acc=21.3, loss=2.77]
# split=train:   8%|▊         | 5/60 [00:00<00:01, 41.32it/s, acc=21.3, loss=2.77]
# split=train:   8%|▊         | 5/60 [00:00<00:01, 41.32it/s, acc=21.4, loss=2.77]
# split=train:  10%|█         | 6/60 [00:00<00:01, 41.32it/s, acc=21.4, loss=2.77]
# split=train:  12%|█▏        | 7/60 [00:00<00:01, 41.32it/s, acc=21.4, loss=2.77]
# split=train:  13%|█▎        | 8/60 [00:00<00:01, 41.32it/s, acc=21.6, loss=2.77]
# split=train:  15%|█▌        | 9/60 [00:00<00:01, 41.32it/s, acc=21.7, loss=2.77]
# split=train:  17%|█▋        | 10/60 [00:00<00:01, 41.52it/s, acc=21.7, loss=2.77]
# split=train:  17%|█▋        | 10/60 [00:00<00:01, 41.52it/s, acc=21.8, loss=2.76]
# split=train:  18%|█▊        | 11/60 [00:00<00:01, 41.52it/s, acc=21.9, loss=2.76]
# split=train:  20%|██        | 12/60 [00:00<00:01, 41.52it/s, acc=21.9, loss=2.76]
# split=train:  22%|██▏       | 13/60 [00:00<00:01, 41.52it/s, acc=21.9, loss=2.76]
# split=train:  23%|██▎       | 14/60 [00:00<00:01, 41.52it/s, acc=22, loss=2.76]
# split=train:  25%|██▌       | 15/60 [00:00<00:01, 41.75it/s, acc=22, loss=2.76]
# split=train:  25%|██▌       | 15/60 [00:00<00:01, 41.75it/s, acc=22, loss=2.76]
# split=train:  27%|██▋       | 16/60 [00:00<00:01, 41.75it/s, acc=22.1, loss=2.76]
# split=train:  28%|██▊       | 17/60 [00:00<00:01, 41.75it/s, acc=22.1, loss=2.76]
# split=train:  30%|███       | 18/60 [00:00<00:01, 41.75it/s, acc=22.1, loss=2.76]
# split=train:  32%|███▏      | 19/60 [00:00<00:00, 41.75it/s, acc=22.1, loss=2.76]
# split=train:  33%|███▎      | 20/60 [00:00<00:00, 40.39it/s, acc=22.1, loss=2.76]
# split=train:  33%|███▎      | 20/60 [00:00<00:00, 40.39it/s, acc=22.2, loss=2.76]
# split=train:  35%|███▌      | 21/60 [00:00<00:00, 40.39it/s, acc=22.1, loss=2.76]
# split=train:  37%|███▋      | 22/60 [00:00<00:00, 40.39it/s, acc=22.1, loss=2.76]
# split=train:  38%|███▊      | 23/60 [00:00<00:00, 40.39it/s, acc=22.1, loss=2.76]
# split=train:  40%|████      | 24/60 [00:00<00:00, 40.39it/s, acc=22.1, loss=2.76]
# split=train:  42%|████▏     | 25/60 [00:00<00:00, 38.78it/s, acc=22.1, loss=2.76]
# split=train:  42%|████▏     | 25/60 [00:00<00:00, 38.78it/s, acc=22.2, loss=2.75]
# split=train:  43%|████▎     | 26/60 [00:00<00:00, 38.78it/s, acc=22.1, loss=2.75]
# split=train:  45%|████▌     | 27/60 [00:00<00:00, 38.78it/s, acc=22.1, loss=2.75]
# split=train:  47%|████▋     | 28/60 [00:00<00:00, 38.78it/s, acc=22.1, loss=2.75]
# split=train:  48%|████▊     | 29/60 [00:00<00:00, 38.69it/s, acc=22.1, loss=2.75]
# split=train:  48%|████▊     | 29/60 [00:00<00:00, 38.69it/s, acc=22.1, loss=2.75]
# split=train:  50%|█████     | 30/60 [00:00<00:00, 38.69it/s, acc=22.1, loss=2.75]
# split=train:  52%|█████▏    | 31/60 [00:00<00:00, 38.69it/s, acc=22.1, loss=2.75]
# split=train:  53%|█████▎    | 32/60 [00:00<00:00, 38.69it/s, acc=22.2, loss=2.75]
# split=train:  55%|█████▌    | 33/60 [00:00<00:00, 38.69it/s, acc=22.2, loss=2.75]
# split=train:  57%|█████▋    | 34/60 [00:00<00:00, 39.23it/s, acc=22.2, loss=2.75]
# split=train:  57%|█████▋    | 34/60 [00:00<00:00, 39.23it/s, acc=22.3, loss=2.75]
# split=train:  58%|█████▊    | 35/60 [00:00<00:00, 39.23it/s, acc=22.2, loss=2.75]
# split=train:  60%|██████    | 36/60 [00:00<00:00, 39.23it/s, acc=22.3, loss=2.75]
# split=train:  62%|██████▏   | 37/60 [00:00<00:00, 39.23it/s, acc=22.3, loss=2.75]
# split=train:  63%|██████▎   | 38/60 [00:00<00:00, 39.23it/s, acc=22.3, loss=2.75]
# split=train:  65%|██████▌   | 39/60 [00:00<00:00, 40.00it/s, acc=22.3, loss=2.75]
# split=train:  65%|██████▌   | 39/60 [00:00<00:00, 40.00it/s, acc=22.3, loss=2.75]
# split=train:  67%|██████▋   | 40/60 [00:01<00:00, 40.00it/s, acc=22.4, loss=2.75]
# split=train:  68%|██████▊   | 41/60 [00:01<00:00, 40.00it/s, acc=22.5, loss=2.75]
# split=train:  70%|███████   | 42/60 [00:01<00:00, 40.00it/s, acc=22.5, loss=2.74]
# split=train:  72%|███████▏  | 43/60 [00:01<00:00, 40.00it/s, acc=22.5, loss=2.74]
# split=train:  73%|███████▎  | 44/60 [00:01<00:00, 40.73it/s, acc=22.5, loss=2.74]
# split=train:  73%|███████▎  | 44/60 [00:01<00:00, 40.73it/s, acc=22.6, loss=2.74]
# split=train:  75%|███████▌  | 45/60 [00:01<00:00, 40.73it/s, acc=22.6, loss=2.74]
# split=train:  77%|███████▋  | 46/60 [00:01<00:00, 40.73it/s, acc=22.6, loss=2.74]
# split=train:  78%|███████▊  | 47/60 [00:01<00:00, 40.73it/s, acc=22.7, loss=2.74]
# split=train:  80%|████████  | 48/60 [00:01<00:00, 40.73it/s, acc=22.7, loss=2.74]
# split=train:  82%|████████▏ | 49/60 [00:01<00:00, 41.55it/s, acc=22.7, loss=2.74]
# split=train:  82%|████████▏ | 49/60 [00:01<00:00, 41.55it/s, acc=22.7, loss=2.74]
# split=train:  83%|████████▎ | 50/60 [00:01<00:00, 41.55it/s, acc=22.7, loss=2.74]
# split=train:  85%|████████▌ | 51/60 [00:01<00:00, 41.55it/s, acc=22.7, loss=2.74]
# split=train:  87%|████████▋ | 52/60 [00:01<00:00, 41.55it/s, acc=22.7, loss=2.74]
# split=train:  88%|████████▊ | 53/60 [00:01<00:00, 41.55it/s, acc=22.7, loss=2.74]
# split=train:  90%|█████████ | 54/60 [00:01<00:00, 41.59it/s, acc=22.7, loss=2.74]
# split=train:  90%|█████████ | 54/60 [00:01<00:00, 41.59it/s, acc=22.7, loss=2.74]
# split=train:  92%|█████████▏| 55/60 [00:01<00:00, 41.59it/s, acc=22.7, loss=2.74]
# split=train:  93%|█████████▎| 56/60 [00:01<00:00, 41.59it/s, acc=22.7, loss=2.74]
# split=train:  95%|█████████▌| 57/60 [00:01<00:00, 41.59it/s, acc=22.7, loss=2.74]
# split=train:  97%|█████████▋| 58/60 [00:01<00:00, 41.59it/s, acc=22.7, loss=2.74]
# split=train:  98%|█████████▊| 59/60 [00:01<00:00, 40.67it/s, acc=22.7, loss=2.74]
# split=train:  98%|█████████▊| 59/60 [00:01<00:00, 40.67it/s, acc=22.7, loss=2.74]
# split=val: 100%|██████████| 12/12 [00:01<00:00,  7.10it/s, acc=21.8, loss=2.76]
#
# split=val:   0%|          | 0/12 [00:00<?, ?it/s, acc=23.8, loss=2.73]
# split=val:   8%|▊         | 1/12 [00:00<00:00, 32.27it/s, acc=23.5, loss=2.71]
# split=val:  17%|█▋        | 2/12 [00:00<00:00, 41.67it/s, acc=23.9, loss=2.72]
# split=val:  25%|██▌       | 3/12 [00:00<00:00, 44.78it/s, acc=23.9, loss=2.71]
# split=val:  33%|███▎      | 4/12 [00:00<00:00, 48.20it/s, acc=23.9, loss=2.71]
# split=val:  42%|████▏     | 5/12 [00:00<00:00, 51.03it/s, acc=23.9, loss=2.7]
# split=val:  50%|█████     | 6/12 [00:00<00:00, 52.64it/s, acc=23.8, loss=2.71]
# split=val:  58%|█████▊    | 7/12 [00:00<00:00, 60.88it/s, acc=23.8, loss=2.71]
# split=val:  58%|█████▊    | 7/12 [00:00<00:00, 60.88it/s, acc=23.8, loss=2.71]
# split=val:  67%|██████▋   | 8/12 [00:00<00:00, 60.88it/s, acc=23.9, loss=2.71]
# split=val:  75%|███████▌  | 9/12 [00:00<00:00, 60.88it/s, acc=23.9, loss=2.71]
# split=val:  83%|████████▎ | 10/12 [00:00<00:00, 60.88it/s, acc=23.6, loss=2.71]
# training routine:  12%|█▏        | 6/50 [00:10<01:15,  1.73s/it, sample1=Irish->F, sample2=Korean->Nabon]
# split=train: 100%|██████████| 60/60 [00:01<00:00, 35.50it/s, acc=22.7, loss=2.74]
#
# split=train:   0%|          | 0/60 [00:00<?, ?it/s, acc=22.5, loss=2.73]
# split=train:   2%|▏         | 1/60 [00:00<00:02, 20.88it/s, acc=21.7, loss=2.76]
# split=train:   3%|▎         | 2/60 [00:00<00:02, 27.44it/s, acc=22, loss=2.76]
# split=train:   5%|▌         | 3/60 [00:00<00:01, 31.28it/s, acc=22.6, loss=2.74]
# split=train:   7%|▋         | 4/60 [00:00<00:01, 33.64it/s, acc=22.6, loss=2.75]
# split=train:   8%|▊         | 5/60 [00:00<00:01, 41.70it/s, acc=22.6, loss=2.75]
# split=train:   8%|▊         | 5/60 [00:00<00:01, 41.70it/s, acc=22.6, loss=2.73]
# split=train:  10%|█         | 6/60 [00:00<00:01, 41.70it/s, acc=22.7, loss=2.72]
# split=train:  12%|█▏        | 7/60 [00:00<00:01, 41.70it/s, acc=22.8, loss=2.72]
# split=train:  13%|█▎        | 8/60 [00:00<00:01, 41.70it/s, acc=22.7, loss=2.72]
# split=train:  15%|█▌        | 9/60 [00:00<00:01, 41.70it/s, acc=22.8, loss=2.72]
# split=train:  17%|█▋        | 10/60 [00:00<00:01, 40.68it/s, acc=22.8, loss=2.72]
# split=train:  17%|█▋        | 10/60 [00:00<00:01, 40.68it/s, acc=22.9, loss=2.72]
# split=train:  18%|█▊        | 11/60 [00:00<00:01, 40.68it/s, acc=23.1, loss=2.72]
# split=train:  20%|██        | 12/60 [00:00<00:01, 40.68it/s, acc=23.1, loss=2.72]
# split=train:  22%|██▏       | 13/60 [00:00<00:01, 40.68it/s, acc=23.2, loss=2.72]
# split=train:  23%|██▎       | 14/60 [00:00<00:01, 40.68it/s, acc=23.2, loss=2.71]
# split=train:  25%|██▌       | 15/60 [00:00<00:01, 40.37it/s, acc=23.2, loss=2.71]
# split=train:  25%|██▌       | 15/60 [00:00<00:01, 40.37it/s, acc=23.3, loss=2.71]
# split=train:  27%|██▋       | 16/60 [00:00<00:01, 40.37it/s, acc=23.3, loss=2.71]
# split=train:  28%|██▊       | 17/60 [00:00<00:01, 40.37it/s, acc=23.3, loss=2.71]
# split=train:  30%|███       | 18/60 [00:00<00:01, 40.37it/s, acc=23.3, loss=2.71]
# split=train:  32%|███▏      | 19/60 [00:00<00:01, 40.37it/s, acc=23.3, loss=2.71]
# split=train:  33%|███▎      | 20/60 [00:00<00:01, 39.59it/s, acc=23.3, loss=2.71]
# split=train:  33%|███▎      | 20/60 [00:00<00:01, 39.59it/s, acc=23.2, loss=2.7]
# split=train:  35%|███▌      | 21/60 [00:00<00:00, 39.59it/s, acc=23.2, loss=2.7]
# split=train:  37%|███▋      | 22/60 [00:00<00:00, 39.59it/s, acc=23.3, loss=2.7]
# split=train:  38%|███▊      | 23/60 [00:00<00:00, 39.59it/s, acc=23.3, loss=2.7]
# split=train:  40%|████      | 24/60 [00:00<00:00, 39.59it/s, acc=23.2, loss=2.7]
# split=train:  42%|████▏     | 25/60 [00:00<00:00, 40.79it/s, acc=23.2, loss=2.7]
# split=train:  42%|████▏     | 25/60 [00:00<00:00, 40.79it/s, acc=23.3, loss=2.7]
# split=train:  43%|████▎     | 26/60 [00:00<00:00, 40.79it/s, acc=23.3, loss=2.7]
# split=train:  45%|████▌     | 27/60 [00:00<00:00, 40.79it/s, acc=23.3, loss=2.7]
# split=train:  47%|████▋     | 28/60 [00:00<00:00, 40.79it/s, acc=23.3, loss=2.7]
# split=train:  48%|████▊     | 29/60 [00:00<00:00, 40.79it/s, acc=23.3, loss=2.7]
# split=train:  50%|█████     | 30/60 [00:00<00:00, 41.20it/s, acc=23.3, loss=2.7]
# split=train:  50%|█████     | 30/60 [00:00<00:00, 41.20it/s, acc=23.4, loss=2.7]
# split=train:  52%|█████▏    | 31/60 [00:00<00:00, 41.20it/s, acc=23.3, loss=2.7]
# split=train:  53%|█████▎    | 32/60 [00:00<00:00, 41.20it/s, acc=23.3, loss=2.7]
# split=train:  55%|█████▌    | 33/60 [00:00<00:00, 41.20it/s, acc=23.4, loss=2.7]
# split=train:  57%|█████▋    | 34/60 [00:00<00:00, 41.20it/s, acc=23.4, loss=2.7]
# split=train:  58%|█████▊    | 35/60 [00:00<00:00, 40.80it/s, acc=23.4, loss=2.7]
# split=train:  58%|█████▊    | 35/60 [00:00<00:00, 40.80it/s, acc=23.4, loss=2.7]
# split=train:  60%|██████    | 36/60 [00:00<00:00, 40.80it/s, acc=23.4, loss=2.7]
# split=train:  62%|██████▏   | 37/60 [00:00<00:00, 40.80it/s, acc=23.4, loss=2.7]
# split=train:  63%|██████▎   | 38/60 [00:00<00:00, 40.80it/s, acc=23.4, loss=2.7]
# split=train:  65%|██████▌   | 39/60 [00:00<00:00, 40.80it/s, acc=23.4, loss=2.7]
# split=train:  67%|██████▋   | 40/60 [00:00<00:00, 40.97it/s, acc=23.4, loss=2.7]
# split=train:  67%|██████▋   | 40/60 [00:01<00:00, 40.97it/s, acc=23.4, loss=2.7]
# split=train:  68%|██████▊   | 41/60 [00:01<00:00, 40.97it/s, acc=23.3, loss=2.7]
# split=train:  70%|███████   | 42/60 [00:01<00:00, 40.97it/s, acc=23.3, loss=2.7]
# split=train:  72%|███████▏  | 43/60 [00:01<00:00, 40.97it/s, acc=23.3, loss=2.7]
# split=train:  73%|███████▎  | 44/60 [00:01<00:00, 40.97it/s, acc=23.3, loss=2.7]
# split=train:  75%|███████▌  | 45/60 [00:01<00:00, 41.08it/s, acc=23.3, loss=2.7]
# split=train:  75%|███████▌  | 45/60 [00:01<00:00, 41.08it/s, acc=23.3, loss=2.7]
# split=train:  77%|███████▋  | 46/60 [00:01<00:00, 41.08it/s, acc=23.3, loss=2.7]
# split=train:  78%|███████▊  | 47/60 [00:01<00:00, 41.08it/s, acc=23.4, loss=2.7]
# split=train:  80%|████████  | 48/60 [00:01<00:00, 41.08it/s, acc=23.4, loss=2.7]
# split=train:  82%|████████▏ | 49/60 [00:01<00:00, 41.08it/s, acc=23.4, loss=2.7]
# split=train:  83%|████████▎ | 50/60 [00:01<00:00, 41.68it/s, acc=23.4, loss=2.7]
# split=train:  83%|████████▎ | 50/60 [00:01<00:00, 41.68it/s, acc=23.4, loss=2.7]
# split=train:  85%|████████▌ | 51/60 [00:01<00:00, 41.68it/s, acc=23.4, loss=2.7]
# split=train:  87%|████████▋ | 52/60 [00:01<00:00, 41.68it/s, acc=23.4, loss=2.7]
# ...
# split=train:  32%|███▏      | 19/60 [00:02<00:04,  9.02it/s, acc=29, loss=2.41]
# split=train:  32%|███▏      | 19/60 [00:02<00:04,  9.02it/s, acc=29, loss=2.41]
# split=train:  33%|███▎      | 20/60 [00:02<00:04,  9.02it/s, acc=29.1, loss=2.41]
# split=train:  35%|███▌      | 21/60 [00:02<00:04,  9.62it/s, acc=29.1, loss=2.41]
# split=train:  35%|███▌      | 21/60 [00:02<00:04,  9.62it/s, acc=29, loss=2.41]
# split=train:  37%|███▋      | 22/60 [00:02<00:04,  8.87it/s, acc=29, loss=2.41]
# split=train:  37%|███▋      | 22/60 [00:02<00:04,  8.87it/s, acc=28.9, loss=2.41]
# split=train:  38%|███▊      | 23/60 [00:02<00:04,  8.76it/s, acc=28.9, loss=2.41]
# split=train:  38%|███▊      | 23/60 [00:02<00:04,  8.76it/s, acc=28.9, loss=2.41]
# split=train:  40%|████      | 24/60 [00:02<00:04,  8.89it/s, acc=28.9, loss=2.41]
# split=train:  40%|████      | 24/60 [00:03<00:04,  8.89it/s, acc=29, loss=2.41]
# split=train:  42%|████▏     | 25/60 [00:03<00:03,  8.80it/s, acc=29, loss=2.41]
# split=train:  42%|████▏     | 25/60 [00:03<00:03,  8.80it/s, acc=29, loss=2.41]
# split=train:  43%|████▎     | 26/60 [00:03<00:03,  8.80it/s, acc=29, loss=2.41]
# split=train:  45%|████▌     | 27/60 [00:03<00:03,  9.62it/s, acc=29, loss=2.41]
# split=train:  45%|████▌     | 27/60 [00:03<00:03,  9.62it/s, acc=28.9, loss=2.42]
# split=train:  47%|████▋     | 28/60 [00:03<00:03,  9.29it/s, acc=28.9, loss=2.42]
# split=train:  47%|████▋     | 28/60 [00:03<00:03,  9.29it/s, acc=28.9, loss=2.42]
# split=train:  48%|████▊     | 29/60 [00:03<00:03,  9.26it/s, acc=28.9, loss=2.42]
# split=train:  48%|████▊     | 29/60 [00:03<00:03,  9.26it/s, acc=28.8, loss=2.42]
# split=train:  50%|█████     | 30/60 [00:03<00:03,  9.17it/s, acc=28.8, loss=2.42]
# split=train:  50%|█████     | 30/60 [00:03<00:03,  9.17it/s, acc=28.8, loss=2.42]
# split=train:  52%|█████▏    | 31/60 [00:03<00:03,  9.17it/s, acc=28.8, loss=2.42]
# split=train:  53%|█████▎    | 32/60 [00:03<00:02, 10.21it/s, acc=28.8, loss=2.42]
# split=train:  53%|█████▎    | 32/60 [00:03<00:02, 10.21it/s, acc=28.9, loss=2.42]
# split=train:  55%|█████▌    | 33/60 [00:03<00:02,  9.66it/s, acc=28.9, loss=2.42]
# split=train:  55%|█████▌    | 33/60 [00:03<00:02,  9.66it/s, acc=28.9, loss=2.42]
# split=train:  57%|█████▋    | 34/60 [00:03<00:02,  9.51it/s, acc=28.9, loss=2.42]
# split=train:  57%|█████▋    | 34/60 [00:04<00:02,  9.51it/s, acc=28.9, loss=2.41]
# split=train:  58%|█████▊    | 35/60 [00:04<00:02,  9.24it/s, acc=28.9, loss=2.41]
# split=train:  58%|█████▊    | 35/60 [00:04<00:02,  9.24it/s, acc=28.9, loss=2.41]
# split=train:  60%|██████    | 36/60 [00:04<00:02,  8.59it/s, acc=28.9, loss=2.41]
# split=train:  60%|██████    | 36/60 [00:04<00:02,  8.59it/s, acc=28.9, loss=2.41]
# split=train:  62%|██████▏   | 37/60 [00:04<00:02,  8.90it/s, acc=28.9, loss=2.41]
# split=train:  62%|██████▏   | 37/60 [00:04<00:02,  8.90it/s, acc=28.9, loss=2.41]
# split=train:  63%|██████▎   | 38/60 [00:04<00:02,  9.17it/s, acc=28.9, loss=2.41]
# split=train:  63%|██████▎   | 38/60 [00:04<00:02,  9.17it/s, acc=28.8, loss=2.42]
# split=train:  65%|██████▌   | 39/60 [00:04<00:02,  9.24it/s, acc=28.8, loss=2.42]
# split=train:  65%|██████▌   | 39/60 [00:04<00:02,  9.24it/s, acc=28.8, loss=2.42]
# split=train:  67%|██████▋   | 40/60 [00:04<00:02,  9.20it/s, acc=28.8, loss=2.42]
# split=train:  67%|██████▋   | 40/60 [00:04<00:02,  9.20it/s, acc=28.9, loss=2.42]
# split=train:  68%|██████▊   | 41/60 [00:04<00:02,  9.20it/s, acc=28.9, loss=2.42]
# split=train:  70%|███████   | 42/60 [00:04<00:01, 10.41it/s, acc=28.9, loss=2.42]
# split=train:  70%|███████   | 42/60 [00:04<00:01, 10.41it/s, acc=28.9, loss=2.42]
# split=train:  72%|███████▏  | 43/60 [00:04<00:01, 10.41it/s, acc=28.9, loss=2.42]
# split=train:  73%|███████▎  | 44/60 [00:04<00:01, 10.70it/s, acc=28.9, loss=2.42]
# split=train:  73%|███████▎  | 44/60 [00:05<00:01, 10.70it/s, acc=28.9, loss=2.42]
# split=train:  75%|███████▌  | 45/60 [00:05<00:01, 10.70it/s, acc=28.9, loss=2.42]
# split=train:  77%|███████▋  | 46/60 [00:05<00:01, 10.84it/s, acc=28.9, loss=2.42]
# split=train:  77%|███████▋  | 46/60 [00:05<00:01, 10.84it/s, acc=28.9, loss=2.42]
# split=train:  78%|███████▊  | 47/60 [00:05<00:01, 10.84it/s, acc=28.9, loss=2.42]
# split=train:  80%|████████  | 48/60 [00:05<00:01,  9.80it/s, acc=28.9, loss=2.42]
# split=train:  80%|████████  | 48/60 [00:05<00:01,  9.80it/s, acc=28.9, loss=2.42]
# split=train:  82%|████████▏ | 49/60 [00:05<00:01,  9.60it/s, acc=28.9, loss=2.42]
# split=train:  82%|████████▏ | 49/60 [00:05<00:01,  9.60it/s, acc=28.9, loss=2.42]
# split=train:  83%|████████▎ | 50/60 [00:05<00:01,  9.60it/s, acc=28.8, loss=2.42]
# split=train:  85%|████████▌ | 51/60 [00:05<00:00, 10.22it/s, acc=28.8, loss=2.42]
# split=train:  85%|████████▌ | 51/60 [00:05<00:00, 10.22it/s, acc=28.8, loss=2.42]
# split=train:  87%|████████▋ | 52/60 [00:05<00:00, 10.22it/s, acc=28.8, loss=2.42]
# split=train:  88%|████████▊ | 53/60 [00:05<00:00,  9.99it/s, acc=28.8, loss=2.42]
# split=train:  88%|████████▊ | 53/60 [00:05<00:00,  9.99it/s, acc=28.8, loss=2.42]
# split=train:  90%|█████████ | 54/60 [00:06<00:00,  9.99it/s, acc=28.8, loss=2.42]
# split=train:  92%|█████████▏| 55/60 [00:06<00:00, 10.37it/s, acc=28.8, loss=2.42]
# split=train:  92%|█████████▏| 55/60 [00:06<00:00, 10.37it/s, acc=28.8, loss=2.42]
# split=train:  93%|█████████▎| 56/60 [00:06<00:00, 10.37it/s, acc=28.8, loss=2.42]
# split=train:  95%|█████████▌| 57/60 [00:06<00:00,  9.66it/s, acc=28.8, loss=2.42]
# split=train:  95%|█████████▌| 57/60 [00:06<00:00,  9.66it/s, acc=28.9, loss=2.42]
# split=train:  97%|█████████▋| 58/60 [00:06<00:00,  9.66it/s, acc=28.8, loss=2.42]
# split=train:  98%|█████████▊| 59/60 [00:06<00:00, 10.24it/s, acc=28.8, loss=2.42]
# split=train:  98%|█████████▊| 59/60 [00:06<00:00, 10.24it/s, acc=28.8, loss=2.42]
# split=val: 100%|██████████| 12/12 [00:06<00:00,  1.73it/s, acc=28.2, loss=2.45]
#
# split=val:   0%|          | 0/12 [00:00<?, ?it/s, acc=29.2, loss=2.39]
# split=val:   8%|▊         | 1/12 [00:00<00:00, 17.24it/s, acc=28.9, loss=2.42]
# split=val:  17%|█▋        | 2/12 [00:00<00:00, 22.46it/s, acc=28.4, loss=2.42]
# split=val:  25%|██▌       | 3/12 [00:00<00:00, 25.42it/s, acc=28.5, loss=2.43]
# split=val:  33%|███▎      | 4/12 [00:00<00:00, 33.33it/s, acc=28.5, loss=2.43]
# split=val:  33%|███▎      | 4/12 [00:00<00:00, 33.33it/s, acc=28.3, loss=2.43]
# split=val:  42%|████▏     | 5/12 [00:00<00:00, 33.33it/s, acc=28.2, loss=2.43]
# split=val:  50%|█████     | 6/12 [00:00<00:00, 33.33it/s, acc=28.3, loss=2.44]
# split=val:  58%|█████▊    | 7/12 [00:00<00:00, 33.33it/s, acc=28.6, loss=2.44]
# split=val:  67%|██████▋   | 8/12 [00:00<00:00, 33.49it/s, acc=28.6, loss=2.44]
# split=val:  67%|██████▋   | 8/12 [00:00<00:00, 33.49it/s, acc=28.7, loss=2.44]
# split=val:  75%|███████▌  | 9/12 [00:00<00:00, 33.49it/s, acc=28.6, loss=2.44]
# split=val:  83%|████████▎ | 10/12 [00:00<00:00, 33.49it/s, acc=28.7, loss=2.44]
# split=val:  92%|█████████▏| 11/12 [00:00<00:00, 33.49it/s, acc=28.7, loss=2.44]
# training routine:  98%|█████████▊| 49/50 [01:56<00:06,  6.04s/it, sample1=Vietnamese->Cha, sample2=Arabic->Kalowa]
# split=train: 100%|██████████| 60/60 [00:06<00:00,  8.69it/s, acc=28.8, loss=2.42]
#
# split=train:   0%|          | 0/60 [00:00<?, ?it/s, acc=29.8, loss=2.38]
# split=train:   2%|▏         | 1/60 [00:00<00:11,  5.35it/s, acc=30.2, loss=2.38]
# split=train:   3%|▎         | 2/60 [00:00<00:05, 10.58it/s, acc=30.2, loss=2.38]
# split=train:   3%|▎         | 2/60 [00:00<00:05, 10.58it/s, acc=30.3, loss=2.39]
# split=train:   5%|▌         | 3/60 [00:00<00:05, 10.58it/s, acc=29.6, loss=2.4]
# split=train:   7%|▋         | 4/60 [00:00<00:05, 10.72it/s, acc=29.6, loss=2.4]
# split=train:   7%|▋         | 4/60 [00:00<00:05, 10.72it/s, acc=29.6, loss=2.4]
# split=train:   8%|▊         | 5/60 [00:00<00:05, 10.72it/s, acc=29.1, loss=2.41]
# split=train:  10%|█         | 6/60 [00:00<00:04, 12.84it/s, acc=29.1, loss=2.41]
# split=train:  10%|█         | 6/60 [00:00<00:04, 12.84it/s, acc=29.1, loss=2.41]
# split=train:  12%|█▏        | 7/60 [00:00<00:04, 12.84it/s, acc=29.3, loss=2.41]
# split=train:  13%|█▎        | 8/60 [00:00<00:04, 12.52it/s, acc=29.3, loss=2.41]
# split=train:  13%|█▎        | 8/60 [00:00<00:04, 12.52it/s, acc=29.2, loss=2.41]
# split=train:  15%|█▌        | 9/60 [00:00<00:04, 12.52it/s, acc=29.5, loss=2.4]
# split=train:  17%|█▋        | 10/60 [00:00<00:03, 12.68it/s, acc=29.5, loss=2.4]
# split=train:  17%|█▋        | 10/60 [00:00<00:03, 12.68it/s, acc=29.4, loss=2.4]
# split=train:  18%|█▊        | 11/60 [00:00<00:03, 12.68it/s, acc=29.4, loss=2.41]
# split=train:  20%|██        | 12/60 [00:00<00:03, 13.64it/s, acc=29.4, loss=2.41]
# split=train:  20%|██        | 12/60 [00:00<00:03, 13.64it/s, acc=29.3, loss=2.41]
# split=train:  22%|██▏       | 13/60 [00:01<00:03, 13.64it/s, acc=29.2, loss=2.41]
# split=train:  23%|██▎       | 14/60 [00:01<00:03, 14.68it/s, acc=29.2, loss=2.41]
# split=train:  23%|██▎       | 14/60 [00:01<00:03, 14.68it/s, acc=29.1, loss=2.41]
# split=train:  25%|██▌       | 15/60 [00:01<00:03, 14.68it/s, acc=29.1, loss=2.41]
# split=train:  27%|██▋       | 16/60 [00:01<00:02, 15.48it/s, acc=29.1, loss=2.41]
# split=train:  27%|██▋       | 16/60 [00:01<00:02, 15.48it/s, acc=29, loss=2.41]
# split=train:  28%|██▊       | 17/60 [00:01<00:02, 15.48it/s, acc=29, loss=2.41]
# split=train:  30%|███       | 18/60 [00:01<00:02, 14.38it/s, acc=29, loss=2.41]
# split=train:  30%|███       | 18/60 [00:01<00:02, 14.38it/s, acc=29, loss=2.41]
# split=train:  32%|███▏      | 19/60 [00:01<00:02, 14.38it/s, acc=29, loss=2.41]
# split=train:  33%|███▎      | 20/60 [00:01<00:02, 13.54it/s, acc=29, loss=2.41]
# split=train:  33%|███▎      | 20/60 [00:01<00:02, 13.54it/s, acc=28.9, loss=2.41]
# split=train:  35%|███▌      | 21/60 [00:01<00:02, 13.54it/s, acc=28.9, loss=2.41]
# split=train:  37%|███▋      | 22/60 [00:01<00:03, 12.47it/s, acc=28.9, loss=2.41]
# split=train:  37%|███▋      | 22/60 [00:01<00:03, 12.47it/s, acc=28.9, loss=2.41]
# split=train:  38%|███▊      | 23/60 [00:01<00:02, 12.47it/s, acc=29, loss=2.41]
# split=train:  40%|████      | 24/60 [00:01<00:02, 12.18it/s, acc=29, loss=2.41]
# split=train:  40%|████      | 24/60 [00:01<00:02, 12.18it/s, acc=29, loss=2.41]
# split=train:  42%|████▏     | 25/60 [00:02<00:02, 12.18it/s, acc=29, loss=2.41]
# split=train:  43%|████▎     | 26/60 [00:02<00:02, 12.05it/s, acc=29, loss=2.41]
# split=train:  43%|████▎     | 26/60 [00:02<00:02, 12.05it/s, acc=28.9, loss=2.41]
# split=train:  45%|████▌     | 27/60 [00:02<00:02, 12.05it/s, acc=28.9, loss=2.41]
# split=train:  47%|████▋     | 28/60 [00:02<00:02, 11.71it/s, acc=28.9, loss=2.41]
# split=train:  47%|████▋     | 28/60 [00:02<00:02, 11.71it/s, acc=28.8, loss=2.41]
# split=train:  48%|████▊     | 29/60 [00:02<00:02, 11.71it/s, acc=28.8, loss=2.41]
# split=train:  50%|█████     | 30/60 [00:02<00:02, 10.50it/s, acc=28.8, loss=2.41]
# split=train:  50%|█████     | 30/60 [00:02<00:02, 10.50it/s, acc=28.9, loss=2.41]
# split=train:  52%|█████▏    | 31/60 [00:02<00:02, 10.50it/s, acc=28.8, loss=2.41]
# split=train:  53%|█████▎    | 32/60 [00:02<00:03,  9.17it/s, acc=28.8, loss=2.41]
# split=train:  53%|█████▎    | 32/60 [00:02<00:03,  9.17it/s, acc=28.8, loss=2.42]
# split=train:  55%|█████▌    | 33/60 [00:02<00:03,  8.15it/s, acc=28.8, loss=2.42]
# split=train:  55%|█████▌    | 33/60 [00:03<00:03,  8.15it/s, acc=28.8, loss=2.42]
# split=train:  57%|█████▋    | 34/60 [00:03<00:03,  8.40it/s, acc=28.8, loss=2.42]
# split=train:  57%|█████▋    | 34/60 [00:03<00:03,  8.40it/s, acc=28.8, loss=2.42]
# split=train:  58%|█████▊    | 35/60 [00:03<00:02,  8.37it/s, acc=28.8, loss=2.42]
# split=train:  58%|█████▊    | 35/60 [00:03<00:02,  8.37it/s, acc=28.8, loss=2.42]
# split=train:  60%|██████    | 36/60 [00:03<00:02,  8.37it/s, acc=28.8, loss=2.42]
# split=train:  62%|██████▏   | 37/60 [00:03<00:02,  8.56it/s, acc=28.8, loss=2.42]
# split=train:  62%|██████▏   | 37/60 [00:03<00:02,  8.56it/s, acc=28.8, loss=2.42]
# split=train:  63%|██████▎   | 38/60 [00:03<00:02,  8.64it/s, acc=28.8, loss=2.42]
# split=train:  63%|██████▎   | 38/60 [00:03<00:02,  8.64it/s, acc=28.8, loss=2.42]
# split=train:  65%|██████▌   | 39/60 [00:03<00:02,  8.64it/s, acc=28.8, loss=2.42]
# split=train:  67%|██████▋   | 40/60 [00:03<00:01, 10.58it/s, acc=28.8, loss=2.42]
# split=train:  67%|██████▋   | 40/60 [00:03<00:01, 10.58it/s, acc=28.9, loss=2.42]
# split=train:  68%|██████▊   | 41/60 [00:03<00:01, 10.58it/s, acc=28.9, loss=2.41]
# split=train:  70%|███████   | 42/60 [00:03<00:01, 12.12it/s, acc=28.9, loss=2.41]
# split=train:  70%|███████   | 42/60 [00:03<00:01, 12.12it/s, acc=28.9, loss=2.41]
# split=train:  72%|███████▏  | 43/60 [00:03<00:01, 12.12it/s, acc=28.9, loss=2.41]
# split=train:  73%|███████▎  | 44/60 [00:03<00:01, 11.98it/s, acc=28.9, loss=2.41]
# split=train:  73%|███████▎  | 44/60 [00:04<00:01, 11.98it/s, acc=28.9, loss=2.41]
# split=train:  75%|███████▌  | 45/60 [00:04<00:01, 11.98it/s, acc=28.9, loss=2.41]
# split=train:  77%|███████▋  | 46/60 [00:04<00:01, 10.78it/s, acc=28.9, loss=2.41]
# split=train:  77%|███████▋  | 46/60 [00:04<00:01, 10.78it/s, acc=28.9, loss=2.41]
# split=train:  78%|███████▊  | 47/60 [00:04<00:01, 10.78it/s, acc=28.9, loss=2.41]
# split=train:  80%|████████  | 48/60 [00:04<00:01, 10.32it/s, acc=28.9, loss=2.41]
# split=train:  80%|████████  | 48/60 [00:04<00:01, 10.32it/s, acc=28.9, loss=2.41]
# split=train:  82%|████████▏ | 49/60 [00:04<00:01, 10.32it/s, acc=28.9, loss=2.41]
# split=train:  83%|████████▎ | 50/60 [00:04<00:01,  9.34it/s, acc=28.9, loss=2.41]
# split=train:  83%|████████▎ | 50/60 [00:04<00:01,  9.34it/s, acc=28.9, loss=2.41]
# split=train:  85%|████████▌ | 51/60 [00:04<00:00,  9.34it/s, acc=28.8, loss=2.41]
# split=train:  87%|████████▋ | 52/60 [00:04<00:00,  9.27it/s, acc=28.8, loss=2.41]
# split=train:  87%|████████▋ | 52/60 [00:04<00:00,  9.27it/s, acc=28.8, loss=2.42]
# split=train:  88%|████████▊ | 53/60 [00:04<00:00,  9.12it/s, acc=28.8, loss=2.42]
# split=train:  88%|████████▊ | 53/60 [00:05<00:00,  9.12it/s, acc=28.8, loss=2.41]
# split=train:  90%|█████████ | 54/60 [00:05<00:00,  8.69it/s, acc=28.8, loss=2.41]
# split=train:  90%|█████████ | 54/60 [00:05<00:00,  8.69it/s, acc=28.8, loss=2.42]
# split=train:  92%|█████████▏| 55/60 [00:05<00:00,  8.56it/s, acc=28.8, loss=2.42]
# split=train:  92%|█████████▏| 55/60 [00:05<00:00,  8.56it/s, acc=28.8, loss=2.41]
# split=train:  93%|█████████▎| 56/60 [00:05<00:00,  8.56it/s, acc=28.8, loss=2.41]
# split=train:  95%|█████████▌| 57/60 [00:05<00:00, 10.32it/s, acc=28.8, loss=2.41]
# split=train:  95%|█████████▌| 57/60 [00:05<00:00, 10.32it/s, acc=28.8, loss=2.41]
# split=train:  97%|█████████▋| 58/60 [00:05<00:00, 10.32it/s, acc=28.8, loss=2.41]
# split=train:  98%|█████████▊| 59/60 [00:05<00:00, 10.49it/s, acc=28.8, loss=2.41]
# split=train:  98%|█████████▊| 59/60 [00:05<00:00, 10.49it/s, acc=28.8, loss=2.41]
# split=val: 100%|██████████| 12/12 [00:05<00:00,  2.01it/s, acc=28.7, loss=2.44]
#
# split=val:   0%|          | 0/12 [00:00<?, ?it/s, acc=28.3, loss=2.39]
# split=val:   8%|▊         | 1/12 [00:00<00:00, 16.13it/s, acc=28.6, loss=2.41]
# split=val:  17%|█▋        | 2/12 [00:00<00:00, 21.98it/s, acc=27.7, loss=2.41]
# split=val:  25%|██▌       | 3/12 [00:00<00:00, 22.56it/s, acc=27.7, loss=2.42]
# split=val:  33%|███▎      | 4/12 [00:00<00:00, 29.63it/s, acc=27.7, loss=2.42]
# split=val:  33%|███▎      | 4/12 [00:00<00:00, 29.63it/s, acc=28.3, loss=2.43]
# split=val:  42%|████▏     | 5/12 [00:00<00:00, 29.63it/s, acc=28.1, loss=2.43]
# split=val:  50%|█████     | 6/12 [00:00<00:00, 29.63it/s, acc=27.9, loss=2.43]
# split=val:  58%|█████▊    | 7/12 [00:00<00:00, 29.52it/s, acc=27.9, loss=2.43]
# split=val:  58%|█████▊    | 7/12 [00:00<00:00, 29.52it/s, acc=28, loss=2.43]
# split=val:  67%|██████▋   | 8/12 [00:00<00:00, 29.52it/s, acc=27.8, loss=2.44]
# split=val:  75%|███████▌  | 9/12 [00:00<00:00, 29.52it/s, acc=27.8, loss=2.44]
# split=val:  83%|████████▎ | 10/12 [00:00<00:00, 29.52it/s, acc=27.9, loss=2.44]
# split=val:  92%|█████████▏| 11/12 [00:00<00:00, 30.35it/s, acc=27.9, loss=2.44]
# training routine: 100%|██████████| 50/50 [02:02<00:00,  6.03s/it, sample1=Czech->Czovon, sample2=English->Reinner]

# %%
model.cpu()
print("\nFinal Sampling Results:")
for idx in range(len(vectorizer.nationality_vocab)):
    nationality = vectorizer.nationality_vocab.lookup_index(idx)
    if nationality == 'English':
        print(f"\nSampling for {nationality}:")
        sampled_indices = sample_from_model(model, vectorizer, [idx]*5, temperature=0.7)
        for name in decode_samples(sampled_indices, vectorizer):
            print(f"- {name}")
# Out:
# Final Sampling Results:
#
# Sampling for English:
# - Leghak
# - Far
# - Bangi
# - Shramem
# - Atdur
